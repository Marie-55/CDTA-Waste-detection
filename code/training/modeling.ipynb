# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lvGKnWiIzIf8rksM53WB")
project = rf.workspace("waste-rq8p9").project("garbage-detection-aylah")
version = project.version(14)
dataset = version.download("multiclass")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.2.0-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.6.15)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Collecting pillow-heif<2 (from roboflow)
#   Downloading pillow_heif-1.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# Downloading roboflow-1.2.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 3.0 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.4 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.0 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.2-cp311-cp311-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 51.1 MB/s eta 0:00:00
# Downloading pillow_heif-1.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 64.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: pillow-avif-plugin, filetype, python-dotenv, pillow-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-avif-plugin-1.5.2 pillow-heif-1.0.0 python-dotenv-1.1.1 roboflow-1.2.0
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in garbage-detection-14 to multiclass:: 100%|██████████| 52722/52722 [00:00<00:00, 59098.01it/s]
# Extracting Dataset Version Zip to garbage-detection-14 in multiclass:: 100%|██████████| 1872/1872 [00:00<00:00, 6294.01it/s]

# %% [markdown]
# # Task
# Analyze the loaded dataset by exploring its contents, visualizing annotations, analyzing class distribution, image properties, and annotation properties, and generating reports.

# %% [markdown]
# ## Load the dataset
#
# ### Subtask:
# Load the dataset into a suitable format for analysis, such as a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Inspect the downloaded dataset directory structure to understand how the data is organized and identify the annotation files. Based on the Roboflow download format ("multiclass" which is typically YOLO or VOC), I will assume a common structure like YOLO format with a `data.yaml` file and text files for annotations or VOC with XML files. I need to check the directory to confirm the actual format and file locations.

# %%
import os
import pandas as pd
import yaml
import xml.etree.ElementTree as ET

# Assuming the dataset is downloaded to a directory named 'multiclass'
dataset_dir = 'multiclass'

# Inspect the directory structure
print(os.listdir(dataset_dir))
print(os.listdir(os.path.join(dataset_dir, 'train')))
print(os.listdir(os.path.join(dataset_dir, 'valid')))
print(os.listdir(os.path.join(dataset_dir, 'test')))

# Try to locate a data.yaml file (common in YOLO format)
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
if os.path.exists(data_yaml_path):
    print(f"\nFound data.yaml at: {data_yaml_path}")
    with open(data_yaml_path, 'r') as f:
        data_yaml = yaml.safe_load(f)
        print("data.yaml content:")
        print(data_yaml)

# Try to locate annotation files (e.g., .txt for YOLO, .xml for VOC) in train directory
train_dir = os.path.join(dataset_dir, 'train')
train_files = os.listdir(train_dir)
annotation_files = [f for f in train_files if f.endswith(('.txt', '.xml'))]
print(f"\nFound annotation files in train directory (first 10): {annotation_files[:10]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2-2876421847.py in <cell line: 0>()
#       8
#       9 # Inspect the directory structure
# ---> 10 print(os.listdir(dataset_dir))
#      11 print(os.listdir(os.path.join(dataset_dir, 'train')))
#      12 print(os.listdir(os.path.join(dataset_dir, 'valid')))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'multiclass'

# %% [markdown]
# **Reasoning**:
# The previous command failed because the `dataset_dir` was incorrectly assumed to be 'multiclass'. Based on the output of the first cell, the dataset was downloaded to a directory named 'garbage-detection-14' within the 'multiclass' directory. I need to correct the `dataset_dir` path and retry inspecting the directory structure to confirm the dataset format and annotation file locations.

# %%
# Correcting the dataset directory path based on the previous cell's output
dataset_dir = os.path.join('multiclass', 'garbage-detection-14')

# Inspect the directory structure
print(os.listdir(dataset_dir))
print(os.listdir(os.path.join(dataset_dir, 'train')))
print(os.listdir(os.path.join(dataset_dir, 'valid')))
print(os.path.join(dataset_dir, 'test'))

# Try to locate a data.yaml file (common in YOLO format)
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
if os.path.exists(data_yaml_path):
    print(f"\nFound data.yaml at: {data_yaml_path}")
    with open(data_yaml_path, 'r') as f:
        data_yaml = yaml.safe_load(f)
        print("data.yaml content:")
        print(data_yaml)
    class_names = data_yaml['names']
    print(f"Class names: {class_names}")


# Try to locate annotation files (e.g., .txt for YOLO, .xml for VOC) in train directory
train_dir = os.path.join(dataset_dir, 'train')
train_files = os.listdir(train_dir)
annotation_files = [f for f in train_files if f.endswith(('.txt', '.xml'))]
print(f"\nFound annotation files in train directory (first 10): {annotation_files[:10]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3-1323225690.py in <cell line: 0>()
#       3
#       4 # Inspect the directory structure
# ----> 5 print(os.listdir(dataset_dir))
#       6 print(os.listdir(os.path.join(dataset_dir, 'train')))
#       7 print(os.listdir(os.path.join(dataset_dir, 'valid')))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'multiclass/garbage-detection-14'

# %% [markdown]
# **Reasoning**:
# The previous command still failed because the dataset directory path is incorrect. Looking back at the output of the first cell, it seems the dataset was downloaded directly to a directory named 'garbage-detection-14'. I need to correct the `dataset_dir` path again.

# %%
# Correcting the dataset directory path based on the initial download output
dataset_dir = 'garbage-detection-14'

# Inspect the directory structure
print(os.listdir(dataset_dir))
print(os.listdir(os.path.join(dataset_dir, 'train')))
print(os.listdir(os.path.join(dataset_dir, 'valid')))
print(os.path.join(dataset_dir, 'test'))

# Try to locate a data.yaml file (common in YOLO format)
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
if os.path.exists(data_yaml_path):
    print(f"\nFound data.yaml at: {data_yaml_path}")
    with open(data_yaml_path, 'r') as f:
        data_yaml = yaml.safe_load(f)
        print("data.yaml content:")
        print(data_yaml)
    class_names = data_yaml['names']
    print(f"Class names: {class_names}")


# Try to locate annotation files (e.g., .txt for YOLO, .xml for VOC) in train directory
train_dir = os.path.join(dataset_dir, 'train')
train_files = os.listdir(train_dir)
annotation_files = [f for f in train_files if f.endswith(('.txt', '.xml'))]
print(f"\nFound annotation files in train directory (first 10): {annotation_files[:10]}")
# Out:
# ['train', 'valid', 'README.dataset.txt', 'README.roboflow.txt', 'test']
# ['929a16f0-R_1121_jpg.rf.2cb7c158ec86704ec06dc83bccbf35c4.jpg', 'Metal_522_jpg.rf.93481ac49a7ee9b3e52ad1c3aee2ad89.jpg', '5e179e44-R_124_jpg.rf.6411f513560e04588798934206144feb.jpg', 'glass501_jpg.rf.66d6fc358ca4e82acfb182b8c97c7b16.jpg', '15WJGM52A0NZ_jpg.rf.e99547634954f4772b5779df7a350775.jpg', 'Cup_Glass368_jpg.rf.d7683fbadd63fae82c54eb5154cccb70.jpg', 'Metal_524_jpg.rf.e3ea149c3cbac729e3262200430437f1.jpg', 'glass43_jpg.rf.65dfced2bd06a0cd65c5f0a6c586dce3.jpg', 'Cup_Glass076_jpg.rf.6a8d47c024bc984cdcbc9f90c2aea0c4.jpg', 'metal593_jpg.rf.77f46166ce48e9ecc2cdd7ad7031972c.jpg', 'Cup_Glass113_jpg.rf.d90be4497c5415557381e2edfc3319db.jpg', '0478E1ES35FY_jpg.rf.72ff927e2136d592bacc5d7433e67697.jpg', '4dafb
2e0074cb37e8613298bcc.jpg', 'Metal_81_jpg.rf.d26b311751d6360d0caf877c4c74d3d3.jpg', '993d629c-R_1045_jpg.rf.807d27643842aac5fcf372cb274b1323.jpg', 'ac75d28e-R_1241_jpg.rf.67763609b322d052a12a43ed24f69e67.jpg', 'Cup_Glass354_jpg.rf.05b07de49787f4e61d48d34942e38b38.jpg', 'p_sm_46_jpg.rf.83bb015c80d9d4a859d1d9ab40eee7e8.jpg', '60ml-Oral-syringe-by-terumo-1_jpg.rf.f3f93557ae5ff0dbceb80e1a836b217d.jpg', '6af3aff6-R_14_jpg.rf.2b2bfc8d9602c9a0562beed45e381560.jpg', 'Cup_Glass065_jpg.rf.70b664c92700f58c1ccf176d2ea33c2a.jpg', '489837a4-R_242_jpg.rf.285090022233f26af43b4e01777482ae.jpg', 'Metal_59_jpg.rf.229e4da67b4597f82776aa59663b0bc7.jpg', '3YX3X5QVHPNC_jpg.rf.325738bfe1969c320fee0db630a5d075.jpg', 'glass231_jpg.rf.7cea0dbd23e3b7ec92d4d0288d9c25b3.jpg', '7c3f7fca-R_1027_jpg.rf.007857689f51a31956b9b03a229ef003.jpg', 'broken_glass_bottle-041_jpg.rf.94c4058e99f52f306bbd1a8b830cd8e7.jpg', 'glass218_jpg.rf.8c4c6305a61052d7a9d8dbb888424a19. ...
# garbage-detection-14/test
#
# Found annotation files in train directory (first 10): []

# %% [markdown]
# **Reasoning**:
# The directory structure confirms that the dataset is in YOLO format, with image files and corresponding `.txt` annotation files in the 'train', 'valid', and 'test' subdirectories. The `data.yaml` file provides the class names. I need to write code to iterate through the annotation files, parse the YOLO format bounding box data and class IDs, convert the bounding box format if necessary (YOLO is center_x, center_y, width, height normalized), and store this information in a pandas DataFrame. I will process the 'train', 'valid', and 'test' sets and combine the annotations into a single DataFrame, adding a 'split' column to indicate the original split.

# %%
# Function to parse YOLO annotation files
def parse_yolo_annotation(annotation_path, image_width, image_height, class_names):
    annotations = []
    with open(annotation_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            class_id = int(parts[0])
            # YOLO format: class_id center_x center_y width height (normalized)
            center_x, center_y, width, height = map(float, parts[1:])

            # Convert to x_min, y_min, x_max, y_max (absolute)
            x_min = (center_x - width / 2) * image_width
            y_min = (center_y - height / 2) * image_height
            x_max = (center_x + width / 2) * image_width
            y_max = (center_y + height / 2) * image_height

            class_name = class_names[class_id]
            annotations.append({
                'class_id': class_id,
                'class_name': class_name,
                'x_min': x_min,
                'y_min': y_min,
                'x_max': x_max,
                'y_max': y_max
            })
    return annotations

# Get image dimensions (assuming all images have the same dimensions, or we'd need to read each image)
# For now, I'll make a placeholder assumption. A more robust approach would be to read image files.
# Let's assume typical image sizes or get from data.yaml if available (often not the case for dimensions)
# A safer approach is to get dimensions from the image files themselves.
# Let's get dimensions from one image file in the training set.
from PIL import Image

image_files = [f for f in train_files if f.endswith(('.jpg', '.jpeg', '.png'))]
if not image_files:
    raise FileNotFoundError("No image files found in the training directory.")

sample_image_path = os.path.join(train_dir, image_files[0])
with Image.open(sample_image_path) as img:
    image_width, image_height = img.size
    print(f"Sample image dimensions: {image_width}x{image_height}")


all_annotations = []
splits = ['train', 'valid', 'test']

for split in splits:
    split_dir = os.path.join(dataset_dir, split)
    image_files = [f for f in os.listdir(split_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

    for image_file in image_files:
        annotation_file = os.path.splitext(image_file)[0] + '.txt'
        annotation_path = os.path.join(split_dir, annotation_file)

        if os.path.exists(annotation_path):
            # Get image dimensions for this specific image
            image_path = os.path.join(split_dir, image_file)
            try:
                with Image.open(image_path) as img:
                    img_width, img_height = img.size
            except Exception as e:
                print(f"Could not read image {image_path}: {e}")
                continue # Skip this image if dimensions cannot be read

            annotations = parse_yolo_annotation(annotation_path, img_width, img_height, class_names)
            for ann in annotations:
                ann['image_filename'] = image_file
                ann['split'] = split
                all_annotations.append(ann)
        else:
            print(f"Annotation file not found for image: {image_file}")


# Create a pandas DataFrame from the collected annotations
annotations_df = pd.DataFrame(all_annotations)

# Display the first few rows of the DataFrame
display(annotations_df.head())

# Display some basic info about the DataFrame
print("\nDataFrame Info:")
annotations_df.info()

# Display the number of annotations per split
print("\nNumber of annotations per split:")
print(annotations_df['split'].value_counts())

# Display the number of annotations per class
print("\nNumber of annotations per class:")
print(annotations_df['class_name'].value_counts())
# Out:
# Sample image dimensions: 640x480
# Annotation file not found for image: 929a16f0-R_1121_jpg.rf.2cb7c158ec86704ec06dc83bccbf35c4.jpg
# Annotation file not found for image: Metal_522_jpg.rf.93481ac49a7ee9b3e52ad1c3aee2ad89.jpg
# Annotation file not found for image: 5e179e44-R_124_jpg.rf.6411f513560e04588798934206144feb.jpg
# Annotation file not found for image: glass501_jpg.rf.66d6fc358ca4e82acfb182b8c97c7b16.jpg
# Annotation file not found for image: 15WJGM52A0NZ_jpg.rf.e99547634954f4772b5779df7a350775.jpg
# Annotation file not found for image: Cup_Glass368_jpg.rf.d7683fbadd63fae82c54eb5154cccb70.jpg
# Annotation file not found for image: Metal_524_jpg.rf.e3ea149c3cbac729e3262200430437f1.jpg
# Annotation file not found for image: glass43_jpg.rf.65dfced2bd06a0cd65c5f0a6c586dce3.jpg
# Annotation file not found for image: Cup_Glass076_jpg.rf.6a8d47c024bc984cdcbc9f90c2aea0c4.jpg
# Annotation file not found for image: metal593_jpg.rf.77f46166ce48e9ecc2cdd7ad7031972c.jpg
# Annotation file not found for image: Cup_Glass113_jpg.rf.d90be4497c5415557381e2edfc3319db.jpg
# Annotation file not found for image: 0478E1ES35FY_jpg.rf.72ff927e2136d592bacc5d7433e67697.jpg
# Annotation file not found for image: 4dafbe19-R_1598_jpg.rf.1986e1f54ad655d1fb9d9dae832f9f5c.jpg
# Annotation file not found for image: R_5267_jpg.rf.d976ab11d7460c82cba71cf2546fb35f.jpg
# Annotation file not found for image: 9c34aae2-R_1295_jpg.rf.c74ffaf620c5493e00fc3e6f97c1a75c.jpg
# Annotation file not found for image: glass438_jpg.rf.03e859393d575d5e70bc426037793487.jpg
# Annotation file not found for image: p_sm_36_jpg.rf.9cbfb37f044541677f2b45f794117b6f.jpg
# Annotation file not found for image: Cup_Glass301_jpg.rf.5617b25f2c2145bb081deb73405c4ca3.jpg
# Annotation file not found for image: glass-280_jpg.rf.2a9322dfc93e529549cf718f658ae0df.jpg
# Annotation file not found for image: 20221020_120040_jpg.rf.669621022e757e1d39f86a7085303c0d.jpg
# Annotation file not found for image: d05547bd-R_1016_jpg.rf.c5d19b25b6ca3e53451e14fbf1aef595.jpg
# Annotation file not found for image: Cup_Glass249_jpg.rf.e177ce9675b9b13104862c7641041759.jpg
# Annotation file not found for image: 33463035-R_1021_jpg.rf.76a95c8525614ef74c9e269ca553dec2.jpg
# Annotation file not found for image: e590f612-R_272_jpg.rf.8ae7fbe599d434e4fc0568e89f7374eb.jpg
# Annotation file not found for image: glass-337_jpg.rf.eb57307e1248b6c27cbf24aa5dcb9ee6.jpg
# Annotation file not found for image: Metal_453_jpg.rf.743adaf61a1f4f1c0812e043dd085315.jpg
# Annotation file not found for image: 96_jpg.rf.9882f5a7fd49bd730d82afe16f8d2503.jpg
# Annotation file not found for image: R_5175_jpg.rf.8c5970a9b99f6ddea7483267dce471bf.jpg
# Annotation file not found for image: 95464255-R_121_jpg.rf.718f77313e9a119b00c0134982387bbe.jpg
# Annotation file not found for image: metal387_jpg.rf.ba8c7fe33d28d194d49a68f566d95da2.jpg
# Annotation file not found for image: R_5197_jpg.rf.5c681cc38d2e60382d5837b0e65f7125.jpg
# Annotation file not found for image: R_5236_jpg.rf.784782dd64d0b0b7bfebd9caf67cea7f.jpg
# Annotation file not found for image: 2961a3ac-R_1206_jpg.rf.7e32c6d3645288ad8afbf2a8afe52721.jpg
# Annotation file not found for image: 60_jpg.rf.92e6bee7fb259979042930a56ecfd383.jpg
# Annotation file not found for image: metal469_jpg.rf.6cdde9695a633d02cb03b6d9e189171f.jpg
# Annotation file not found for image: metal738_jpg.rf.e9a97c4aa4aa1c490085437dbd41782a.jpg
# Annotation file not found for image: Cup_Glass185_jpg.rf.00d72ccdced45ab0e6b8b599c71109e9.jpg
# Annotation file not found for image: Cup_Glass198_jpg.rf.06222c4f6a9af8459c6746925a2c6841.jpg
# Annotation file not found for image: Metal_447_jpg.rf.a34c7ae619faea7707296931b07c4dac.jpg
# Annotation file not found for image: glass330_jpg.rf.916973e37d70b0c73f4d4f09d61796c9.jpg
# Annotation file not found for image: f900e62b-R_1421_jpg.rf.6a38b97617a90cc047cf843def5f78b1.jpg
# Annotation file not found for image: 6dcf2959-R_985_jpg.rf.34e0923a9121ba18e3cfb47b373fb827.jpg
# Annotation file not found for image: Cup_Glass373_jpg.rf.10630773a53bcd1c10f1badf7edb363a.jpg
# Annotation file not found for image: glass356_jpg.rf.da69d744506d1fce330126a6daa8458a.jpg
# Annotation file not found for image: glass88_jpg.rf.c30837f0cf81cad3ef10f4ea5459005d.jpg
# Annotation file not found for image: 63_jpg.rf.8975109b869d3cc991f41720f6451f8f.jpg
# Annotation file not found for image: glass-398_jpg.rf.f18c596856ac0bebe63c705f7b978d53.jpg
# Annotation file not found for image: R_5159_jpg.rf.dfb607e5e27ce2c0bcd2baa5b60a54bc.jpg
# Annotation file not found for image: 547c92dd-R_263_jpg.rf.2e68d5455743f6d95be21558e0d4a388.jpg
# Annotation file not found for image: Cup_Glass189_jpg.rf.eebc0526a7b2d85aaa84888d88217137.jpg
# Annotation file not found for image: glass282_jpg.rf.993835abbe660c0e71215bf6ab0ac4cd.jpg
# Annotation file not found for image: R_5119_jpg.rf.593bc8c7516e5cdb9e4a4aa0ff20b1cc.jpg
# Annotation file not found for image: Cup_Glass190_jpg.rf.88e1467d980918dad1c2e6a10ed0580c.jpg
# Annotation file not found for image: 9f8c6c64-R_1167_jpg.rf.4ef777d4d68c26503287eb3ff42b9e9c.jpg
# Annotation file not found for image: metal520_jpg.rf.6ba76ff59140ce6488800c3b23efe1db.jpg
# Annotation file not found for image: glass-224_jpg.rf.2f6ed96a063fb8f0e58f822b59eafb4d.jpg
# Annotation file not found for image: glass387_jpg.rf.b930b2c8653704825db430e7a8b67591.jpg
# Annotation file not found for image: 3e98bfda-R_1393_jpg.rf.305ac80873bff0ddc9fb62cf9d6f95d1.jpg
# Annotation file not found for image: glass268_jpg.rf.f203345486b213b0065e9afb7ea11694.jpg
# Annotation file not found for image: metal573_jpg.rf.eebf6ea9a662c1bc14c19e566db46810.jpg
# Annotation file not found for image: c47ecb46-R_175_jpg.rf.79a3ad618c9de600d408e7d560b1e4b3.jpg
# Annotation file not found for image: Metal_n_399_jpg.rf.7b48fbdd6cc686e7dbb74b615c0c4894.jpg
# Annotation file not found for image: glass244_jpg.rf.29ac23fb18be2121b994673edf589e7d.jpg
# Annotation file not found for image: e15b9f00-R_983_jpg.rf.adac01aaa58cb295638d2495d996d65e.jpg
# Annotation file not found for image: 3140e259-R_1557_jpg.rf.ba9c3f22a82d37c27dcbdf09ae53ce60.jpg
# Annotation file not found for image: glass34_jpg.rf.4cc6f4c4397fcd106bdb9779453e6162.jpg
# Annotation file not found for image: glass-236_jpg.rf.ec72fad93c8c01fdb7ff8a8003804278.jpg
# Annotation file not found for image: glass137_jpg.rf.3bfad4440d6a64a413700a92b367c90c.jpg
# Annotation file not found for image: 20221020_121815_jpg.rf.55e2d542495172043719b13c77011121.jpg
# Annotation file not found for image: glass165_jpg.rf.209f0eaeae98a44ce846b87445926cfa.jpg
# Annotation file not found for image: Metal_573_jpg.rf.3d65a3c3d282e119b0b2eb0aecd7c52d.jpg
# Annotation file not found for image: ce18d081-R_1054_jpg.rf.8267c927fb05ddd0ad98770670d6589a.jpg
# Annotation file not found for image: Cup_Glass370_jpg.rf.d30b52197c7d8077a059652e8677df2d.jpg
# Annotation file not found for image: e0de2087-R_1042_jpg.rf.3939e0fc39445a7c86c9ed81a968da65.jpg
# Annotation file not found for image: glass9_jpg.rf.273de28b6c54b0fb27a55d9a1842f8f4.jpg
# Annotation file not found for image: 554a3b3b-R_105_jpg.rf.d73595071a62c8083d5176c483b61e9a.jpg
# Annotation file not found for image: Cup_Glass367_jpg.rf.eea9c814a40e30d6f43b9bd3247d03e8.jpg
# Annotation file not found for image: Metal_420_jpg.rf.45e04a220ebb717aedd8f9721ae3e1fc.jpg
# Annotation file not found for image: Metal_152_jpg.rf.ab40bb4e6ec5c86adad1e012f53a664b.jpg
# Annotation file not found for image: a2bb4dba-R_1527_jpg.rf.3104909a2c9ca43a6bf06b582035342d.jpg
# Annotation file not found for image: Cup_Glass350_jpg.rf.16d82909551f2c4cc11b7a66fd1fc4cf.jpg
# Annotation file not found for image: glass398_jpg.rf.672956c9c53e25fbf287030c499af667.jpg
# Annotation file not found for image: 0Z43YYDJZCMH_jpg.rf.35fe978f49cfe9beb439c508e20dbf4f.jpg
# Annotation file not found for image: c298a47b-R_993_jpg.rf.4b1fcbbed354ae828399c7bec368e0a1.jpg
# Annotation file not found for image: c6c9658a-R_71_jpg.rf.96d346fc1ac555ef22f972c0167bfe73.jpg
# Annotation file not found for image: Cup_Glass223_jpg.rf.11d7f9e5c1432784f228fde4044eac35.jpg
# Annotation file not found for image: Metal_399_jpg.rf.bf0dbdd877843444fcc2763525a3ab2e.jpg
# Annotation file not found for image: glass215_jpg.rf.9bfe371a622eb386065eae42ca468262.jpg
# Annotation file not found for image: Metal_638_jpg.rf.c407b519474d3b5ee132550adf4d4b0b.jpg
# Annotation file not found for image: Cup_Glass342_jpg.rf.cac87145043b3050f2d97c2ae46ea3b6.jpg
# Annotation file not found for image: 69ded349-R_1090_jpg.rf.e933dc7ebd6217c5062a5ff8ba14a3c2.jpg
# Annotation file not found for image: c4e89fe1-R_47_jpg.rf.8c6a6bf6dd39a04f1362ba665cc95a03.jpg
# Annotation file not found for image: glass-324_jpg.rf.8faa615fc6b7e7b37b3b80e106a51d7e.jpg
# Annotation file not found for image: 87_jpg.rf.1a8013516bf8987408105dbbc6659ea9.jpg
# Annotation file not found for image: Cup_Glass387_jpg.rf.bdc2de0dc2ccfa235d427dc8a83b3c06.jpg
# Annotation file not found for image: Metal_652_jpg.rf.ae949a41fe4ccdc1e58d5205439064a6.jpg
# Annotation file not found for image: 9a72413b-R_27_jpg.rf.7aa9dbcb05644a1e063c4dd49f974d02.jpg
# Annotation file not found for image: glass430_jpg.rf.2040f74382b2737361f469d43330a494.jpg
# Annotation file not found for image: Metal_n_393_jpg.rf.fc7212ac65ce9eea98782228e61c179e.jpg
# Annotation file not found for image: 3b6f2fc8-R_32_jpg.rf.592aac955691797ce74055c1d42a0c85.jpg
# Annotation file not found for image: 12856a5c-R_1014_jpg.rf.de8854bad7a7de3c968fcd19a812c019.jpg
# Annotation file not found for image: R_5114_jpg.rf.071f6554caf5bdf06206e9e676b97ec1.jpg
# Annotation file not found for image: R_5071_jpg.rf.71ac15ecaa62fb137b78947bce2f607d.jpg
# Annotation file not found for image: glass476_jpg.rf.171c60b9ae029cbcf424c496e0c290e0.jpg
# Annotation file not found for image: p_sm_3_jpg.rf.67e60b550cf59841b72948b1d1e5721e.jpg
# Annotation file not found for image: glass389_jpg.rf.1ae80f6dadbcae9dd3f65296567d4c4d.jpg
# Annotation file not found for image: 20237d3f-R_94_jpg.rf.471969501af8add1ba45ad0da9882657.jpg
# Annotation file not found for image: 18961bf8-R_973_jpg.rf.4ceadc0c3ffe0bf003e32315e79b3416.jpg
# Annotation file not found for image: metal93_jpg.rf.25a612caae655e01ab4c6d22fa479aac.jpg
# Annotation file not found for image: glass-352_jpg.rf.2875c02d5783b4db1f8f93421fe30077.jpg
# Annotation file not found for image: 20221020_121359_jpg.rf.e4e4324754a564aaef497ba451a01684.jpg
# Annotation file not found for image: glass-470_jpg.rf.b26e6891a2adea9965e226f635b959c9.jpg
# Annotation file not found for image: Cup_Glass322_jpg.rf.4e89340ac07c71383cab2999d2810e96.jpg
# Annotation file not found for image: f0e9bd63-R_1479_jpg.rf.f13cc262a846aa25ee9fc957d8d4a996.jpg
# Annotation file not found for image: glass-450_jpg.rf.43e3ab66adc3a65c4460ceadc1fdc041.jpg
# Annotation file not found for image: R_5284_jpg.rf.d72761d091fa3d62c4b401e4bc22be8f.jpg
# Annotation file not found for image: A13_jpg.rf.598b84f3bd1bfab1e99d6ffdaef2086a.jpg
# Annotation file not found for image: 83d84d5e-R_218_jpg.rf.372d7b39bdb6cd31379dfce4c0760aa1.jpg
# Annotation file not found for image: glass249_jpg.rf.2f355c32ef9e8c69a3a35a5a5421ca80.jpg
# Annotation file not found for image: Cup_Glass149_jpg.rf.100e13e63268646f7e9aa58ec30b1988.jpg
# Annotation file not found for image: 3a54bf9d-R_1580_jpg.rf.0f459675a303f980a3144d24b631fc4c.jpg
# Annotation file not found for image: Metal_551_jpg.rf.ae32355049d770e49315f987761e9324.jpg
# Annotation file not found for image: glass119_jpg.rf.59aab8201f0414a56c7f3d1480ec8e0b.jpg
# Annotation file not found for image: 20221019_141251_jpg.rf.6eac875e6494acde053585d825ca94db.jpg
# Annotation file not found for image: glass114_jpg.rf.4052771f4830bdd33a470f49255366b5.jpg
# Annotation file not found for image: Cup_Glass144_jpg.rf.57a69a5f2ea69da18f6e09a9c2bd3b91.jpg
# Annotation file not found for image: d97e16d0-R_1209_jpg.rf.023bc3fae83ad4f5d381e17a4122b202.jpg
# Annotation file not found for image: c63abe1d-R_1566_jpg.rf.9252cabda2e1824059e57313c24ffbaa.jpg
# Annotation file not found for image: Metal_565_jpg.rf.3009efb6256afdbefb4db7f2ac9b697a.jpg
# Annotation file not found for image: Metal_614_jpg.rf.b8b8f3c6e5741cbc74e969a9c2671817.jpg
# Annotation file not found for image: Cup_Glass258_jpg.rf.9ccb7469a0d6ba0d99c1d868f4d4aa0e.jpg
# Annotation file not found for image: 15peko_jpg.rf.127ce32e418c55819e79bbbc68329b91.jpg
# Annotation file not found for image: metal551_jpg.rf.0a6bcc077be2552423f5be1c1c47a1d3.jpg
# Annotation file not found for image: A70_jpg.rf.18ba35c6261915ca49bcf09d76c79cc4.jpg
# Annotation file not found for image: 101021fd4e5c7292_jpg.rf.b0812d5e7b079a59c979079fe6baa7f4.jpg
# Annotation file not found for image: Metal_42_jpg.rf.e09576796beea9ac0f7affe0e6f81bf9.jpg
# Annotation file not found for image: 20221019_141252_jpg.rf.f6940050ca0d9e2518566e2d815ea49a.jpg
# Annotation file not found for image: Cup_Glass321_jpg.rf.c2ce40f0551f3268b426d8072f298468.jpg
# Annotation file not found for image: Cup_Glass203_jpg.rf.1ef6169eb2d0f712a27b6f1df4b798ad.jpg
# Annotation file not found for image: glass314_jpg.rf.ee3487b604e221580cd65a6c57a13b15.jpg
# Annotation file not found for image: glass372_jpg.rf.63a8f302713e2292ff80f6d2df2a9168.jpg
# Annotation file not found for image: glass302_jpg.rf.b4308dc6c4565e85187841cff4106cec.jpg
# Annotation file not found for image: glass412_jpg.rf.b4148338d63fdd9a71e3162bb789b817.jpg
# Annotation file not found for image: glass-402_jpg.rf.e27b74b3a96e623598d5457d8557ba70.jpg
# Annotation file not found for image: 3a86c676-R_152_jpg.rf.ef0a77dca236978b4b83119ea0171e36.jpg
# Annotation file not found for image: 20221020_120436_jpg.rf.3df6461c3d4e6bed59454e88fe750ddb.jpg
# Annotation file not found for image: R_5081_jpg.rf.0381a88ef484c9408c066163210f2828.jpg
# Annotation file not found for image: p_sm_10_jpg.rf.19dbb7f051ba78a79173b638a9e0d7b1.jpg
# Annotation file not found for image: 20221020_120323_jpg.rf.a31687d84628d36f159eba8804aeff66.jpg
# Annotation file not found for image: R_5155_jpg.rf.32b784348d739f54b467997a058a5d1b.jpg
# Annotation file not found for image: dac1104a-R_1425_jpg.rf.2f30f863d504173c923493a12062be42.jpg
# Annotation file not found for image: 0TGO7GMYCWKN_jpg.rf.0b361b198cdc0d66a2a481804f2433cc.jpg
# Annotation file not found for image: 3LI8TBZ7M4N6_jpg.rf.5ffc99fa01eee6ef8930c7f6d4488436.jpg
# Annotation file not found for image: Metal_722_jpg.rf.686886b5fc1eb99905defeb14b5f3c35.jpg
# Annotation file not found for image: Cup_Glass227_jpg.rf.05fbb18af0b36d7f7004f4cefb9522ff.jpg
# Annotation file not found for image: Metal_107_jpg.rf.9fad9be4e7b23f8ce624d7a53608b4bc.jpg
# Annotation file not found for image: 1FR0DMICQHD0_jpg.rf.d439d8d22cfa5f102cffff83303b20bc.jpg
# Annotation file not found for image: Metal_82_jpg.rf.f313a30482eaffdf250db5273d90b19a.jpg
# Annotation file not found for image: p_sm_11_jpg.rf.97d9969e471dbeea044788236666aad0.jpg
# Annotation file not found for image: R_5212_jpg.rf.1f4cd7b36e040d5857723c4c4b17deff.jpg
# Annotation file not found for image: R_5223_jpg.rf.ce160698de472308dac88ce243f1b481.jpg
# Annotation file not found for image: b13cbcc4-R_114_jpg.rf.aec590f11e1bb2c7aa917f2e9dfb5df5.jpg
# Annotation file not found for image: Cup_Glass388_jpg.rf.58d97f98524dde7dc0903778daaf436b.jpg
# Annotation file not found for image: glass105_jpg.rf.c3f9e1142f80c37d2719cd2ae2b968a3.jpg
# Annotation file not found for image: 267fc685-R_1395_jpg.rf.fb07f5017880ac54c142a19e6af3cba8.jpg
# Annotation file not found for image: glass130_jpg.rf.f8e513830d8d92ecf9215489fc79951d.jpg
# Annotation file not found for image: R_5099_jpg.rf.d3f152cb219f09249585ec8c2220aa2b.jpg
# Annotation file not found for image: glass78_jpg.rf.97b69d7f9a09f47e5fb507c04e5f3dd1.jpg
# Annotation file not found for image: glass274_jpg.rf.d77adee462775b9fcfb8a5708f38e1d9.jpg
# Annotation file not found for image: Metal_n_400_jpg.rf.e2200ba5310e81444586c15cdb3c41b7.jpg
# Annotation file not found for image: glass251_jpg.rf.d9e6a5fec33d7ecc767da99ee8b3e54a.jpg
# Annotation file not found for image: Metal_58_jpg.rf.0247ab7f96f3bd12614d9119fcaed99a.jpg
# Annotation file not found for image: 20221020_120612_jpg.rf.055b573fbc76650155599d2e30c2891b.jpg
# Annotation file not found for image: glass460_jpg.rf.d2e548ba0f2348a28382198bfa078022.jpg
# Annotation file not found for image: glass29_jpg.rf.d2e5ce5a93bbb209a0fe562e0d1358de.jpg
# Annotation file not found for image: glass-365_jpg.rf.8bdb1c71dd2033c4b865b3fecdbcdb1b.jpg
# Annotation file not found for image: Cup_Glass104_jpg.rf.c97a2e51a393ccf892be38fbefeaac19.jpg
# Annotation file not found for image: glass-413_jpg.rf.2dd33929ce56868d7de86b8a06c1ce2f.jpg
# Annotation file not found for image: 20221020_120403_jpg.rf.cc3c8202ed5e6a8364225a6c2eb21f73.jpg
# Annotation file not found for image: R_5126_jpg.rf.b48c5cfd5290cfc891883384c6954fa5.jpg
# Annotation file not found for image: Cup_Glass366_jpg.rf.2de1c0878261e0839a6ba5b4fd160bb8.jpg
# Annotation file not found for image: glass-417_jpg.rf.1b782c5d39dcc2246f2bf55a738c309c.jpg
# Annotation file not found for image: glass27_jpg.rf.f88f0a3cf5783456c798b81c7a0a0a69.jpg
# Annotation file not found for image: glass386_jpg.rf.41e23ed427655ccc4249fd0ff5098ea6.jpg
# Annotation file not found for image: 2335ecd0-R_29_jpg.rf.59c4bdddb6db5471bf9e257b2f43319e.jpg
# Annotation file not found for image: glass316_jpg.rf.b1f588a87978c314b78e44d3846b4539.jpg
# Annotation file not found for image: glass446_jpg.rf.ca9074fb953118fd3f3efc2218946556.jpg
# Annotation file not found for image: glass185_jpg.rf.85ef41129a8d14c9790d6ad215d21b81.jpg
# Annotation file not found for image: b1487e53-R_1559_jpg.rf.01c3954e76028baa9efec1ff964fc36e.jpg
# Annotation file not found for image: fc76ff46-R_157_jpg.rf.8b2ffd5d49d72e8fc1276bf12b2821fa.jpg
# Annotation file not found for image: a4df97fd-R_996_jpg.rf.08238c78c868f34cc9853f5a4e02e5f1.jpg
# Annotation file not found for image: 20221019_141126_jpg.rf.d3fda4a6e0f6532ee3fd5f070b9dec91.jpg
# Annotation file not found for image: Metal_672_jpg.rf.71a86f0aa40cbc3ffdf299d29068f506.jpg
# Annotation file not found for image: Cup_Glass142_jpg.rf.3f3d39637b50037d1f1778a88f686a77.jpg
# Annotation file not found for image: 20221019_141151_jpg.rf.477035672e4e2fd47958c0355a1d097f.jpg
# Annotation file not found for image: glass420_jpg.rf.381a96cc59cdb6dc07314d992914ee6d.jpg
# Annotation file not found for image: 92_jpg.rf.89c1baa54753c69552a1a6cb35646efd.jpg
# Annotation file not found for image: 1421dea9fb39e5bc_jpg.rf.873b361680ac3fa2202b133b3789ab48.jpg
# Annotation file not found for image: 49dfa076-R_205_jpg.rf.cea5a9a526c3ef103601c19889a8e12c.jpg
# Annotation file not found for image: e146c2f5-R_1282_jpg.rf.f7b451119c226960d24f7f642fa61677.jpg
# Annotation file not found for image: Metal_54_jpg.rf.2a228b49e9b9c4b3c6df530927f6eb03.jpg
# Annotation file not found for image: 40_jpg.rf.68b5dc43d20e3e204dab2bef825b9337.jpg
# Annotation file not found for image: glass371_jpg.rf.a31d2afe2ae0f0ebc885751bf88ae564.jpg
# Annotation file not found for image: glass171_jpg.rf.37b0608228fbd35e4f69e1e5750b9724.jpg
# Annotation file not found for image: e311440c-R_201_jpg.rf.dbac428dd8ef5b6a7cd6f772f3274a0e.jpg
# Annotation file not found for image: metal594_jpg.rf.aa00aa7ab5d76667f8fcdd2892200873.jpg
# Annotation file not found for image: Cup_Glass316_jpg.rf.6a0737ea846c1f394906955eb51d6a49.jpg
# Annotation file not found for image: metal627_jpg.rf.8b8c3f26e5d45a76a0666723ab5c5cc9.jpg
# Annotation file not found for image: glass-389_jpg.rf.283d409a2ac9b348ec2a6d3dc8eab211.jpg
# Annotation file not found for image: f3590fa0-R_52_jpg.rf.489087ae18799de32a5e077917380f95.jpg
# Annotation file not found for image: glass246_jpg.rf.3f2738e9c9732b3b5c0b383b212f9f62.jpg
# Annotation file not found for image: R_5273_jpg.rf.b7a795fa83390c0d787e9a2edf34ff9c.jpg
# Annotation file not found for image: glass71_jpg.rf.f769ac8592d66b586cd9150a6935deba.jpg
# Annotation file not found for image: Metal_n_437_jpg.rf.2e2dcb364f563e755a143f2d6fec4b93.jpg
# Annotation file not found for image: Metal_506_jpg.rf.5e60f423afbe8e1e1138160fb68539e4.jpg
# Annotation file not found for image: A81_jpg.rf.3b73e9143613f83dc5e1bcbf5a285bb5.jpg
# Annotation file not found for image: add6036c-R_1005_jpg.rf.7fdc19c8c98241f3c78793a505b75c80.jpg
# Annotation file not found for image: f11b15ef-R_1517_jpg.rf.662ab68ea847742290517f070176cf9b.jpg
# Annotation file not found for image: metal602_jpg.rf.e6bcea376791a654f6779413163b0c62.jpg
# Annotation file not found for image: glass-64_jpg.rf.e0011f421b5f3ce0a9d699cdfc94817d.jpg
# Annotation file not found for image: p_sm_26_jpg.rf.6b7eac69ccd80ae777b330c811653273.jpg
# Annotation file not found for image: metal578_jpg.rf.5e27dd867b346eec90b0c115aa592634.jpg
# Annotation file not found for image: Cup_Glass086_jpg.rf.2b444f0e5332137fcfe8757823878bf8.jpg
# Annotation file not found for image: 53_png.rf.80df98d11cf9a1511012dab3050a9f2a.jpg
# Annotation file not found for image: 710dd15f-R_1345_jpg.rf.90cd8b4d050d223a74e2845a8bbc0e2f.jpg
# Annotation file not found for image: Metal_606_jpg.rf.603003286d620866de291752f7884a0a.jpg
# Annotation file not found for image: metal47_jpg.rf.6be15b48113991d1a8edfbda02565245.jpg
# Annotation file not found for image: 0PX8016S26LM_jpg.rf.86441d838eb073377d74d7dd586e4f1b.jpg
# Annotation file not found for image: glass195_jpg.rf.d702c16f66bb3d9aedc8d77f834f41d1.jpg
# Annotation file not found for image: R_5189_jpg.rf.2a568fb11ad389acfa360169cc01ee8a.jpg
# Annotation file not found for image: Metal_186_jpg.rf.72a6fd5ceb18fbc7a886e19b672f412d.jpg
# Annotation file not found for image: 20221020_120722_jpg.rf.9d3cc56f712c11c52cdaf52b80cd63e1.jpg
# Annotation file not found for image: 117CYNCKDCS3_jpg.rf.a2b6a3c495eb77fd804b457d61b8c738.jpg
# Annotation file not found for image: 852384a6-R_967_jpg.rf.b50c073880fdf1cedc27a942bb02d3bc.jpg
# Annotation file not found for image: b8acf6e3-R_1055_jpg.rf.4ef8b1d53585492180e6eff7dc8b15ea.jpg
# Annotation file not found for image: glass-495_jpg.rf.2a3843b82e60cd03ad53cee2e95f03d9.jpg
# Annotation file not found for image: 761d0b88-R_233_jpg.rf.85e4410dd34d21bd026341dedba0332a.jpg
# Annotation file not found for image: Metal_310_jpg.rf.24a2322da09bf8b0b1be227a68acc87f.jpg
# Annotation file not found for image: fd4c1fb9-R_44_jpg.rf.5908479c8d128bb88dbfce05fbc83c30.jpg
# Annotation file not found for image: Cup_Glass039_jpg.rf.9d67f0226c1e764a7ea14883e7ad7d9e.jpg
# Annotation file not found for image: glass-512_jpg.rf.a1dbced99715e38be9cfadbb4aac870c.jpg
# Annotation file not found for image: Cup_Glass355_jpg.rf.1588ccade64b5d6b56613e1921ccbaa3.jpg
# Annotation file not found for image: b2b46738-R_1170_jpg.rf.6e31b67f40c967a2182c02c10f60f7b7.jpg
# Annotation file not found for image: glass147_jpg.rf.4be81cffd2a9e10fb543c22274cc8b21.jpg
# Annotation file not found for image: glass443_jpg.rf.78d6e12098a300410f7df825ae140e71.jpg
# Annotation file not found for image: Cup_Glass378_jpg.rf.0e08b14d900e5b908b22e998967885c3.jpg
# Annotation file not found for image: glass-101_jpg.rf.72044beddcee343523829350a6d50840.jpg
# Annotation file not found for image: glass293_jpg.rf.6765bef47a2a209f1c368798e67613a6.jpg
# Annotation file not found for image: 5da8e493-R_1034_jpg.rf.df6312fd61b2cfd2bd3d908f607aef7a.jpg
# Annotation file not found for image: 20221019_141510_jpg.rf.b57363d9cd7120b44a2ccea7a4684ce5.jpg
# Annotation file not found for image: R_5266_jpg.rf.397a623ba97bf9ad8f13bc101cb3b356.jpg
# Annotation file not found for image: 1PKQ99OZ1920_jpg.rf.c32df952103422748a831721c055064c.jpg
# Annotation file not found for image: Metal_214_jpg.rf.cedc5d621b420d2d2817d0fa721004d2.jpg
# Annotation file not found for image: p_sm_27_jpg.rf.1332b4867b667954835a9dca1b7bdf2f.jpg
# Annotation file not found for image: A38_jpg.rf.0c036a357968218604ae877db1d9bb0b.jpg
# Annotation file not found for image: 20221019_141031_jpg.rf.7af9af63a88d4c5dc73b9d0ecb205b5f.jpg
# Annotation file not found for image: R_5120_jpg.rf.7c250d39d146b3c27ef8841c3615664a.jpg
# Annotation file not found for image: metal645_jpg.rf.06a5bcaad6696d7f16c59d7ba712e98e.jpg
# Annotation file not found for image: glass390_jpg.rf.2d64d5c0c541eb7323019915081e2e31.jpg
# Annotation file not found for image: glass-501_jpg.rf.1f3ca625fbd1f9bc3bd9824345ee1884.jpg
# Annotation file not found for image: glass128_jpg.rf.b92e2ef42fe056b56ad263140b0b0741.jpg
# Annotation file not found for image: glass-181_jpg.rf.640b85f3929848e836cfabc85c303bda.jpg
# Annotation file not found for image: R_5054_jpg.rf.1b6c6f1caf96b9dd17f7a1de6ccef19c.jpg
# Annotation file not found for image: glass-497_jpg.rf.e2cc84b2808a3c1b9e23edccd602aa66.jpg
# Annotation file not found for image: Cup_Glass197_jpg.rf.9e1117d8b02c90f222c114036fcaf9fe.jpg
# Annotation file not found for image: glass135_jpg.rf.792f42dd2cf0f537bbdfdfed1ab2f774.jpg
# Annotation file not found for image: 4e8147f5-R_1081_jpg.rf.88b8b4dc702664c602404b39688f29a6.jpg
# Annotation file not found for image: 9_jpg.rf.48e4d37ffd6b9854b742f48ee3a68206.jpg
# Annotation file not found for image: 025cd8ab-R_1355_jpg.rf.68d429a0221c350dd7021d3d59c6ca8c.jpg
# Annotation file not found for image: 89_jpg.rf.81ed76ded30bc6f62025b735d178749f.jpg
# Annotation file not found for image: Cup_Glass254_jpg.rf.1663a3dfea036fb0c382b733b0a1196f.jpg
# Annotation file not found for image: glass194_jpg.rf.3f88698ca88cc6dcd3c318192ba8a5fd.jpg
# Annotation file not found for image: glass475_jpg.rf.5be30b38304e71189a5370b1be664a96.jpg
# Annotation file not found for image: R_5259_jpg.rf.05fcf7e95150b97fecd54116410f7445.jpg
# Annotation file not found for image: Metal_668_jpg.rf.b799662040b9bd1831032e8727916c40.jpg
# Annotation file not found for image: Metal_21_jpg.rf.6a25e81bd8af672411d1811456631010.jpg
# Annotation file not found for image: 97_jpg.rf.6e1ac2788a8f3d48db452f60745e657d.jpg
# Annotation file not found for image: 74185740-R_963_jpg.rf.368c2ce14616f24f5542868ea3f51646.jpg
# Annotation file not found for image: glass-426_jpg.rf.828f055cc3d5917265d3071b1777d1e0.jpg
# Annotation file not found for image: Cup_Glass295_jpg.rf.b1ba2c391c0b5e633087c5f1b7ad8e7a.jpg
# Annotation file not found for image: 3eed7e93-R_1166_jpg.rf.4cc84db2c513e8689a350faf35f61154.jpg
# Annotation file not found for image: Metal_125_jpg.rf.9a39a0154911eb2a09e6d4a726005ec4.jpg
# Annotation file not found for image: Cup_Glass285_jpg.rf.9007c4737ab6d6aac1956924aba735d0.jpg
# Annotation file not found for image: 20221019_141139_jpg.rf.c3d4c8109e3ec9481b5e86d26678f5af.jpg
# Annotation file not found for image: 20221020_123041_jpg.rf.fd1d7095b3a1234fa0a6d39585f7010c.jpg
# Annotation file not found for image: Metal_105_jpg.rf.9b56d67c6e5a106529037206df37edd0.jpg
# Annotation file not found for image: glass411_jpg.rf.8fb992fa7018bd34526e4c0f2324ec53.jpg
# Annotation file not found for image: A85_jpg.rf.597320d76d75e49d53115ebb30c0917d.jpg
# Annotation file not found for image: ffc8a248-R_1107_jpg.rf.da07e969b68a31dfd324b44d6c80e868.jpg
# Annotation file not found for image: glass448_jpg.rf.789e8b82f5e37d1811552456a273163c.jpg
# Annotation file not found for image: 62_jpg.rf.f00957fa48b638d814656c0c1d8b68ad.jpg
# Annotation file not found for image: Metal_676_jpg.rf.8298c70463099349d67c0bb79d6633b9.jpg
# Annotation file not found for image: 0beffcdd-R_1052_jpg.rf.d42c7802618777af06418b89bb8da1b7.jpg
# Annotation file not found for image: 1EAZZBEYU8G8_jpg.rf.a9e307431f01e792f716fe18cede9587.jpg
# Annotation file not found for image: Metal_714_jpg.rf.02c0ada1e215225af2dfeb4b8ece61d5.jpg
# Annotation file not found for image: glass289_jpg.rf.aea996282fb94dc89bde79cf4423f5af.jpg
# Annotation file not found for image: glass212_jpg.rf.2d5f5f312aece5193d2e77cdb998dabd.jpg
# Annotation file not found for image: d768bbc0-R_214_jpg.rf.3f49532d1abde9a78e21436e97da660a.jpg
# Annotation file not found for image: b74f136a-R_1585_jpg.rf.ac058091a59c5fad7af56170b554a446.jpg
# Annotation file not found for image: metal341_jpg.rf.96e7f322aaa50be20a40d27a759b04b6.jpg
# Annotation file not found for image: Metal_194_jpg.rf.ed34cb8ecb3507fcdf369b4dd7a5b72c.jpg
# Annotation file not found for image: 6f08ea63-R_1029_jpg.rf.808a27c286429580f3f58da864426250.jpg
# Annotation file not found for image: glass-132_jpg.rf.b5980c0316669ccb8332d2d1abfcabeb.jpg
# Annotation file not found for image: 20221020_121331_jpg.rf.0fdc12ea51a9571afa816d0846350fcf.jpg
# Annotation file not found for image: R_5080_jpg.rf.c6cadac50e3d680c55122d5ce9a23115.jpg
# Annotation file not found for image: 97b31ba3-R_229_jpg.rf.7cfd51e3c6999b0649d22ecc390876b7.jpg
# Annotation file not found for image: metal668_jpg.rf.4f77ff24033264dfd99cd5262b3d1768.jpg
# Annotation file not found for image: p_sm_9_jpg.rf.a00e772d12a8c8db16f899e778e8ba2f.jpg
# Annotation file not found for image: R_5244_jpg.rf.7c296d9f7bc23b837d1b3b97c5a506d9.jpg
# Annotation file not found for image: 20221020_121611_jpg.rf.eb7fa480f727fde01b6670e7d385af8d.jpg
# Annotation file not found for image: glass-505_jpg.rf.eaae0aa3a8afe17a3c38351623eeaf9b.jpg
# Annotation file not found for image: Metal_n_388_jpg.rf.0b2d2a2ffb4e13f77ecc9a2a249ddf50.jpg
# Annotation file not found for image: Cup_Glass299_jpg.rf.9f84f754fd0d39a31633b1b8462c1a6e.jpg
# Annotation file not found for image: 19cdf49a-R_1023_jpg.rf.d0fb8d3c7095c3cd86e42b3b26e76090.jpg
# Annotation file not found for image: metal695_jpg.rf.ba53d1518dc5f0e67be9bb96eb7d8bb6.jpg
# Annotation file not found for image: glass-222_jpg.rf.9ab32a1e3c2d8147dda94b41638d00d1.jpg
# Annotation file not found for image: Metal_n_352_jpg.rf.4b21df5f3ae618b144b8d2309215bf40.jpg
# Annotation file not found for image: glass166_jpg.rf.3a1a3b68749d6ca887ce33388200d4a3.jpg
# Annotation file not found for image: glass-178_jpg.rf.b59d3db79f7f35d035ba24b62485f528.jpg
# Annotation file not found for image: glass-141_jpg.rf.87d7a5bd09a4ee92ce0a1809e88f57c3.jpg
# Annotation file not found for image: Metal_415_jpg.rf.4a087407d2b73d462a11050f122dbfec.jpg
# Annotation file not found for image: glass-434_jpg.rf.f5d3b7fa93f7496d373bd3d5be5122b4.jpg
# Annotation file not found for image: R_5191_jpg.rf.5ae5fa8b31bd28ca7aa69a894ceb595e.jpg
# Annotation file not found for image: metal678_jpg.rf.ad626993fac058e322a5f62f33d1ba79.jpg
# Annotation file not found for image: Cup_Glass035_jpg.rf.c5e2e15f61ee589343bb7c878f627af7.jpg
# Annotation file not found for image: glass-519_jpg.rf.4be3757bd1b40d73d5d25c5cd626ed95.jpg
# Annotation file not found for image: glass70_jpg.rf.2dcee2687fd1320ebca565b4e8331634.jpg
# Annotation file not found for image: p_sm_8_jpg.rf.1b86764d2f5927f2c131eb35a04a2030.jpg
# Annotation file not found for image: A90_jpg.rf.347f58e5719cfe5b4621ef5d5b4a6858.jpg
# Annotation file not found for image: glass-357_jpg.rf.77c35d485b3dbced5b7cc4395191505e.jpg
# Annotation file not found for image: d5798b87-R_1348_jpg.rf.efaefb9181f44808ac67fe5171aca918.jpg
# Annotation file not found for image: ca475668-R_1471_jpg.rf.110f4f0df48c0c85b43443caf01a2660.jpg
# Annotation file not found for image: p_sm_44_jpg.rf.07eabe0db891e977744eaee0bb9905f0.jpg
# Annotation file not found for image: ecd29c85-R_1571_jpg.rf.07bcdc53d187f008aac50f574e6afda7.jpg
# Annotation file not found for image: 141_jpg.rf.b81499dc00688aca752ba6427b1ccdba.jpg
# Annotation file not found for image: Metal_122_jpg.rf.a0bf2c46235b6cb7d0272bf47991a345.jpg
# Annotation file not found for image: 00014a42-R_39_jpg.rf.e84a405edf4dcb9447d776855b41f8fd.jpg
# Annotation file not found for image: R_5233_jpg.rf.ba546d776b7787bc7d499df2f4972cbe.jpg
# Annotation file not found for image: 20221020_121920_jpg.rf.021b6bca16fcdf3259e75434481a75e8.jpg
# Annotation file not found for image: metal495_jpg.rf.1f1e8de09a3fa8b53ff80cece2a467b6.jpg
# Annotation file not found for image: 86_jpg.rf.5a7a0baa215b6ddabf102163906ba2bd.jpg
# Annotation file not found for image: A55_jpg.rf.4db4d5ed6df7543ef56e8eb666a975b2.jpg
# Annotation file not found for image: 20221020_121607_jpg.rf.5300891fed22ea91cfb19519a2c2bc18.jpg
# Annotation file not found for image: Cup_Glass218_jpg.rf.4ad176fae4179de0ddd3f0963021b5a1.jpg
# Annotation file not found for image: 93_jpg.rf.80a47c85ba673a37fef8713e35a9a9ea.jpg
# Annotation file not found for image: fa65d79a-R_1231_jpg.rf.5354b12ad7a6bc02e3f966ae15126ba1.jpg
# Annotation file not found for image: 20221020_120434_jpg.rf.58a3ab4ab29e88ed5d0d5ab7f7e733a8.jpg
# Annotation file not found for image: Metal_99_jpg.rf.566b4246910d44b4e3a09bf2d20c5502.jpg
# Annotation file not found for image: Metal_480_jpg.rf.0c673092a6d4e04e7ef25a5cb8fa6226.jpg
# Annotation file not found for image: Cup_Glass093_jpg.rf.8ee7ca3af51cbf735199c275554a18a3.jpg
# Annotation file not found for image: ba854e8f-R_1569_jpg.rf.2aaa2fa3c1cf58d0ff7bea512ea3b669.jpg
# Annotation file not found for image: Cup_Glass160_jpg.rf.e9c4f396cc4b34a5122501a020972eb9.jpg
# Annotation file not found for image: 0WMC0VUOI8D9_jpg.rf.339a3a7efdafe50cb2b70d21ab1845ce.jpg
# Annotation file not found for image: aebd242c-R_1417_jpg.rf.545dbc0d4ac8b703605dc446e5549b48.jpg
# Annotation file not found for image: Metal_242_jpg.rf.086ae4eacfdfc0f8e30f0ffd48a564a1.jpg
# Annotation file not found for image: glass327_jpg.rf.3aca1ca97a0f143b5acc0e6c08b52332.jpg
# Annotation file not found for image: glass253_jpg.rf.f87f6565d2201c7362b52ebb8c153ca7.jpg
# Annotation file not found for image: Metal_145_jpg.rf.3b3b6905487f83b2fd1bd6f150a56daf.jpg
# Annotation file not found for image: Metal_173_jpg.rf.06d61af521bf985d3c43695acd8c59a0.jpg
# Annotation file not found for image: eae2ea6f-R_209_jpg.rf.d798b0bc14376cf774e2ec5361cf1a90.jpg
# Annotation file not found for image: 2014be0963d6756a_jpg.rf.21fb2e77358b9418b9b5b3b92a492416.jpg
# Annotation file not found for image: 20221020_120801_jpg.rf.b2a699485e8e50f89d6dfade07bc8042.jpg
# Annotation file not found for image: 0H0LD8TIES8H_jpg.rf.0f8d2d1cec526e91b7dbb348b1aadb08.jpg
# Annotation file not found for image: Metal_309_jpg.rf.c937c71a214e36ec1e655a577313d6cc.jpg
# Annotation file not found for image: e95115b9-R_1335_jpg.rf.0af7cd56a66b7473fcf958f6c9adf61a.jpg
# Annotation file not found for image: 0H0LD8TIES8H_jpg.rf.5f6086ed7098f026b4eb0662f40eadf7.jpg
# Annotation file not found for image: glass111_jpg.rf.b604680be854b95b64591e23f7c28227.jpg
# Annotation file not found for image: Cup_Glass031_jpg.rf.d4fe3507d875701e5d762db512ed6a7d.jpg
# Annotation file not found for image: glass-76_jpg.rf.9044a5fa849c981b4261299f1acfd6a0.jpg
# Annotation file not found for image: glass477_jpg.rf.e02822aa00293d6491b375787c0c41fc.jpg
# Annotation file not found for image: 25bd015c-R_77_jpg.rf.f6063e75a48903997cf947f68698da7c.jpg
# Annotation file not found for image: glass399_jpg.rf.85196cdd8da76e6b7d093801190b4a27.jpg
# Annotation file not found for image: Metal_572_jpg.rf.8b46952010722365c09a06cf2ca2f352.jpg
# Annotation file not found for image: 98_jpg.rf.d52985a466e3865d2779fce03fc622d7.jpg
# Annotation file not found for image: glass-516_jpg.rf.017d91b084e38c0665e424a64f873148.jpg
# Annotation file not found for image: 20221020_121802_jpg.rf.36c8b5cf85d38ef58a993cc3efde7d4e.jpg
# Annotation file not found for image: R_5134_jpg.rf.0aab069bf71cc89a1fe03cb9ef6cb100.jpg
# Annotation file not found for image: glass-415_jpg.rf.8ce1983f3d2c7d595f683540e402e076.jpg
# Annotation file not found for image: 20221020_121655_jpg.rf.4d34f1fc80db3a75f0d946d2cfcb01be.jpg
# Annotation file not found for image: Cup_Glass207_jpg.rf.7bd786b09a97f157b07666a8d34aa1ca.jpg
# Annotation file not found for image: Cup_Glass059_jpg.rf.e086b57afed7c7a89b0d6a6a37bc0398.jpg
# Annotation file not found for image: 8843e9c8-R_245_jpg.rf.5eb10976a67030235b8be8c310d1549f.jpg
# Annotation file not found for image: 2cac13ba-R_166_jpg.rf.7e18fb235048ac4332dbfe736554ee2f.jpg
# Annotation file not found for image: 20221020_121804_jpg.rf.22f834f2ff2dfecfae55ac579579b310.jpg
# Annotation file not found for image: 48adb1e5-R_992_jpg.rf.5922dad9f9162fb76ba6c700a5227501.jpg
# Annotation file not found for image: 2e00d647dd51af32_jpg.rf.495308bacf669fb85d6aa8c3a9550648.jpg
# Annotation file not found for image: glass456_jpg.rf.194a4e05ff86adfaf380b207f7098ce4.jpg
# Annotation file not found for image: 0d48ff14-R_81_jpg.rf.caf20f92fdd3a9e118457ae1e90611d0.jpg
# Annotation file not found for image: glass142_jpg.rf.67a993d240e031b9cfb251fa8db7b6d6.jpg
# Annotation file not found for image: 20221020_123028_jpg.rf.4c3aeab9f0f5497c92c7ac94c16ebfac.jpg
# Annotation file not found for image: 20221020_121924_jpg.rf.5b66ebbd8ce36c89d6d5a5f2e6ce99fa.jpg
# Annotation file not found for image: 5f98431c-R_966_jpg.rf.1787dfcb48bfc7f01f8c390b514ebc6f.jpg
# Annotation file not found for image: Cup_Glass074_jpg.rf.52e18af6ae92133ff9f6fdda265b2fd3.jpg
# Annotation file not found for image: glass63_jpg.rf.9cbe5d9bd13cf5e7e60fb363b7d0eb16.jpg
# Annotation file not found for image: Metal_120_jpg.rf.cbee48c36212bd0bb355a8db47c8d18b.jpg
# Annotation file not found for image: 3c821bb2-R_1314_jpg.rf.8a6b6748aef6d108533be2727d36f928.jpg
# Annotation file not found for image: 9cdcb9cc-R_1173_jpg.rf.a41e4938cf65473fbb5d040b9ee34018.jpg
# Annotation file not found for image: Metal_207_jpg.rf.f5bf2132a15a9b4e575ca9927b2a3e49.jpg
# Annotation file not found for image: 74_jpg.rf.be3ae54fc5d36ee5459085def4891595.jpg
# Annotation file not found for image: 3CC_Syringe_w_needle_Yellow-B_jpg.rf.442569dd35b99a0a6fdc43189b42c404.jpg
# Annotation file not found for image: glass263_jpg.rf.75219fe7bcba0a348cadbe2738ece5cc.jpg
# Annotation file not found for image: 9906d891-R_60_jpg.rf.e50290a7fee30bb3cb7701985958a9b9.jpg
# Annotation file not found for image: 25095KYW9EQN_jpg.rf.ae82f3030b05fa7db62cd9cbdaf4d7a6.jpg
# Annotation file not found for image: Cup_Glass271_jpg.rf.8e1975a0ace1f176910936647ed82b2e.jpg
# Annotation file not found for image: glass301_jpg.rf.4dc617e2798878f5b193517fe803fdf2.jpg
# Annotation file not found for image: Metal_450_jpg.rf.ae689749d3f3a26b090deae6c798b15e.jpg
# Annotation file not found for image: Cup_Glass090_jpg.rf.5162a4d5eed9027f55b7ae4d51ccb439.jpg
# Annotation file not found for image: glass168_jpg.rf.26d7b859114a087528fe9fe09c4490e9.jpg
# Annotation file not found for image: Metal_521_jpg.rf.7aff1a09e12072e0a36ba3494ea482f9.jpg
# Annotation file not found for image: 1FSD2WP8FG2X_jpg.rf.517ec3da87a3066c6fc2c521b54229d6.jpg
# Annotation file not found for image: 1Q9YEQ43NQKN_jpg.rf.6d9c99c4254c3e6fd699cceee47000a6.jpg
# Annotation file not found for image: 0HA9M8EFZ5QM_jpg.rf.a76cdaf4da6d80c809d6a42c67ef95bf.jpg
# Annotation file not found for image: 33204826-R_98_jpg.rf.da3b6493bfc4da6ededfa529206ab056.jpg
# Annotation file not found for image: 0ND40VPYA44P_jpg.rf.ad0b539a128145ee7ce95ea2155e71a5.jpg
# Annotation file not found for image: glass72_jpg.rf.deeb907e8a8b332171e564a5385df28d.jpg
# Annotation file not found for image: glass347_jpg.rf.e7a5deea62b3dd20488d417b71480197.jpg
# Annotation file not found for image: Cup_Glass061_jpg.rf.6dbe0b9e1727da931c693bb43fc8e91d.jpg
# Annotation file not found for image: Cup_Glass372_jpg.rf.fbd5a5d72a923efa9f9dcd589583c056.jpg
# Annotation file not found for image: 3CT2VBHFQ6R6_jpg.rf.eb7288d0974ee3ba510b6fe09ea7eb15.jpg
# Annotation file not found for image: 69_jpg.rf.8c1906b3b4512f843a9435c3edc910a5.jpg
# Annotation file not found for image: glass240_jpg.rf.1703ba953dad763253efaad8f1871cc4.jpg
# Annotation file not found for image: 20221020_121841_jpg.rf.40c1398e3f163dd6d5b4bed1e4b35145.jpg
# Annotation file not found for image: Metal_155_jpg.rf.71be5c8dc2521ca25c6d5120a16dbcfa.jpg
# Annotation file not found for image: R_5148_jpg.rf.35cd898e16d1974247e7dfa3163ad940.jpg
# Annotation file not found for image: b93cd58f-R_151_jpg.rf.bdb97c4d2b3582266c4a43a3c27baa25.jpg
# Annotation file not found for image: 636ce5e0-R_82_jpg.rf.2ad29be332c5afa6655fc8bad9770935.jpg
# Annotation file not found for image: Metal_527_jpg.rf.2ca2360e0f417320d8185f44387bd017.jpg
# Annotation file not found for image: 3Q7TD2KUVC7I_jpg.rf.74345aa5dc69c9dc2317ccdb3b71073a.jpg
# Annotation file not found for image: Cup_Glass020_jpg.rf.45461d63fbc6769b158129fdaf81594f.jpg
# Annotation file not found for image: glass361_jpg.rf.c7539b68f73bb07fb1b9bdd95fad5faa.jpg
# Annotation file not found for image: R_5144_jpg.rf.32185f0dff8e8da1ba7f78574799c02a.jpg
# Annotation file not found for image: Cup_Glass042_jpg.rf.371408d87bcdca3ddddd355e1601dc02.jpg
# Annotation file not found for image: glass-21_jpg.rf.0564a4cd9556cc948811413b824f03c8.jpg
# Annotation file not found for image: Metal_175_jpg.rf.77f1675f2a2b9ce36deba291f24e73cb.jpg
# Annotation file not found for image: Metal_588_jpg.rf.916c6821072b0dabe03ed67853374939.jpg
# Annotation file not found for image: da4920f7-R_41_jpg.rf.87d80e328ca757ae565c9be1b5a357ad.jpg
# Annotation file not found for image: glass222_jpg.rf.a31d6a3a36a60330f23502ddf750aacf.jpg
# Annotation file not found for image: Metal_587_jpg.rf.e649ff8e350e4b3249b121a2be821a52.jpg
# Annotation file not found for image: 171WAZT3FUZV_jpg.rf.8a1adb25b518a1b25ac44f3bdb99ef4e.jpg
# Annotation file not found for image: Metal_518_jpg.rf.55e0e8cdfaa53c17a6eb9a61971366c8.jpg
# Annotation file not found for image: Metal_671_jpg.rf.d74e74632b2eb0a4069bebba7fb6e6ae.jpg
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
#
# Number of annotations per split:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-5-1653989759.py in <cell line: 0>()
#      85 # Display the number of annotations per split
#      86 print("\nNumber of annotations per split:")
# ---> 87 print(annotations_df['split'].value_counts())
#      88
#      89 # Display the number of annotations per class
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
#     418         self._check_indexing_error(key)
#     419         raise KeyError(key)
#
# KeyError: 'split'

# %% [markdown]
# **Reasoning**:
# The previous code failed because no annotations were found, resulting in an empty DataFrame and a KeyError when trying to access the 'split' column. The "Annotation file not found" messages suggest that the script is looking for annotation files with the same base name as the image files but with a `.txt` extension, which is typical for YOLO format. However, the output shows many image files but no corresponding annotation files are being found. I need to re-examine the file listing from the previous successful step to see if the annotation files have a different naming convention or are located in a different place relative to the images within the split subdirectories. It seems the annotation files might be in a `labels` subdirectory within each split directory, which is also a common YOLO structure. I will modify the code to look for annotations in a 'labels' subdirectory.

# %%
# Correcting the dataset directory path based on the initial download output
dataset_dir = 'garbage-detection-14'

# Function to parse YOLO annotation files
def parse_yolo_annotation(annotation_path, image_width, image_height, class_names):
    annotations = []
    if not os.path.exists(annotation_path):
        # print(f"Annotation file not found: {annotation_path}")
        return annotations # Return empty list if file doesn't exist

    with open(annotation_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                 print(f"Skipping malformed annotation line in {annotation_path}: {line.strip()}")
                 continue

            class_id = int(parts[0])
            # YOLO format: class_id center_x center_y width height (normalized)
            center_x, center_y, width, height = map(float, parts[1:])

            # Convert to x_min, y_min, x_max, y_max (absolute)
            x_min = (center_x - width / 2) * image_width
            y_min = (center_y - height / 2) * image_height
            x_max = (center_x + width / 2) * image_width
            y_max = (center_y + height / 2) * image_height

            if class_id < 0 or class_id >= len(class_names):
                 print(f"Warning: Class ID {class_id} out of bounds in {annotation_path}. Skipping annotation.")
                 continue

            class_name = class_names[class_id]
            annotations.append({
                'class_id': class_id,
                'class_name': class_name,
                'x_min': x_min,
                'y_min': y_min,
                'x_max': x_max,
                'y_max': y_max
            })
    return annotations

# Read class names from data.yaml
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
class_names = []
if os.path.exists(data_yaml_path):
    with open(data_yaml_path, 'r') as f:
        data_yaml = yaml.safe_load(f)
        class_names = data_yaml.get('names', [])
    if not class_names:
        print("Warning: 'names' not found in data.yaml. Class IDs will be used instead.")
        # Create dummy class names if not found
        class_names = [f'class_{i}' for i in range(100)] # Assuming max 100 classes if names are missing


all_annotations = []
splits = ['train', 'valid', 'test']

for split in splits:
    image_dir = os.path.join(dataset_dir, split, 'images')
    label_dir = os.path.join(dataset_dir, split, 'labels')

    if not os.path.exists(image_dir):
        print(f"Image directory not found for split {split}: {image_dir}")
        continue
    if not os.path.exists(label_dir):
        print(f"Label directory not found for split {split}: {label_dir}")
        # If no label directory, maybe annotations are in the same directory as images?
        label_dir = os.path.join(dataset_dir, split)
        print(f"Trying to find labels in: {label_dir}")
        if not os.path.exists(label_dir):
             print(f"No image or label directory found for split {split}")
             continue


    image_files = [f for f in os.listdir(image_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

    for image_file in image_files:
        annotation_file = os.path.splitext(image_file)[0] + '.txt'
        annotation_path = os.path.join(label_dir, annotation_file)

        # Get image dimensions for this specific image
        image_path = os.path.join(image_dir, image_file)
        img_width, img_height = 0, 0 # Initialize dimensions
        try:
            with Image.open(image_path) as img:
                img_width, img_height = img.size
        except Exception as e:
            print(f"Could not read image dimensions for {image_path}: {e}")
            continue # Skip this image if dimensions cannot be read


        annotations = parse_yolo_annotation(annotation_path, img_width, img_height, class_names)
        for ann in annotations:
            ann['image_filename'] = image_file
            ann['split'] = split
            all_annotations.append(ann)


# Create a pandas DataFrame from the collected annotations
annotations_df = pd.DataFrame(all_annotations)

# Display the first few rows of the DataFrame
display(annotations_df.head())

# Display some basic info about the DataFrame
print("\nDataFrame Info:")
annotations_df.info()

# Display the number of annotations per split
print("\nNumber of annotations per split:")
print(annotations_df['split'].value_counts())

# Display the number of annotations per class
print("\nNumber of annotations per class:")
print(annotations_df['class_name'].value_counts())
# Out:
# Image directory not found for split train: garbage-detection-14/train/images
# Image directory not found for split valid: garbage-detection-14/valid/images
# Image directory not found for split test: garbage-detection-14/test/images
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
#
# Number of annotations per split:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-6-353752609.py in <cell line: 0>()
#     110 # Display the number of annotations per split
#     111 print("\nNumber of annotations per split:")
# --> 112 print(annotations_df['split'].value_counts())
#     113
#     114 # Display the number of annotations per class
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
#     418         self._check_indexing_error(key)
#     419         raise KeyError(key)
#
# KeyError: 'split'

# %% [markdown]
# **Reasoning**:
# The previous code failed again because it assumed the images are in a subdirectory named `images` within each split directory (e.g., `train/images`), but the directory listing from the successful step shows that image files and annotation files (presumably) are directly within the split directories (`train`, `valid`, `test`). I need to correct the paths for `image_dir` and `label_dir` to point directly to the split directories. I will also add a check to ensure that the annotation file exists before trying to parse it.

# %%
# Correcting the dataset directory path based on the initial download output
dataset_dir = 'garbage-detection-14'

# Function to parse YOLO annotation files
def parse_yolo_annotation(annotation_path, image_width, image_height, class_names):
    annotations = []
    if not os.path.exists(annotation_path):
        # print(f"Annotation file not found: {annotation_path}") # Keep this commented unless debugging
        return annotations # Return empty list if file doesn't exist

    with open(annotation_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                 print(f"Skipping malformed annotation line in {annotation_path}: {line.strip()}")
                 continue

            try:
                class_id = int(parts[0])
                # YOLO format: class_id center_x center_y width height (normalized)
                center_x, center_y, width, height = map(float, parts[1:])
            except ValueError as e:
                 print(f"Skipping line with invalid format in {annotation_path}: {line.strip()} - {e}")
                 continue


            # Convert to x_min, y_min, x_max, y_max (absolute)
            x_min = (center_x - width / 2) * image_width
            y_min = (center_y - height / 2) * image_height
            x_max = (center_x + width / 2) * image_width
            y_max = (center_y + height / 2) * image_height

            if class_id < 0 or class_id >= len(class_names):
                 print(f"Warning: Class ID {class_id} out of bounds in {annotation_path}. Using class_id as name.")
                 class_name = f'class_{class_id}' # Use generic name if class_id is out of bounds
            else:
                class_name = class_names[class_id]

            annotations.append({
                'class_id': class_id,
                'class_name': class_name,
                'x_min': x_min,
                'y_min': y_min,
                'x_max': x_max,
                'y_max': y_max
            })
    return annotations

# Read class names from data.yaml
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
class_names = []
if os.path.exists(data_yaml_path):
    with open(data_yaml_path, 'r') as f:
        data_yaml = yaml.safe_load(f)
        class_names = data_yaml.get('names', [])
    if not class_names:
        print("Warning: 'names' not found in data.yaml. Class IDs will be used instead.")
        # Create dummy class names if not found (assuming max 100 classes if names are missing)
        class_names = [f'class_{i}' for i in range(100)]
else:
    print("Warning: data.yaml not found. Class IDs will be used instead.")
    # Create dummy class names if data.yaml is not found
    class_names = [f'class_{i}' for i in range(100)]


all_annotations = []
splits = ['train', 'valid', 'test']

for split in splits:
    split_dir = os.path.join(dataset_dir, split)

    if not os.path.exists(split_dir):
        print(f"Split directory not found: {split_dir}")
        continue

    image_files = [f for f in os.listdir(split_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

    for image_file in image_files:
        annotation_file = os.path.splitext(image_file)[0] + '.txt'
        annotation_path = os.path.join(split_dir, annotation_file)

        # Get image dimensions for this specific image
        image_path = os.path.join(split_dir, image_file)
        img_width, img_height = 0, 0 # Initialize dimensions
        try:
            with Image.open(image_path) as img:
                img_width, img_height = img.size
        except Exception as e:
            print(f"Could not read image dimensions for {image_path}: {e}")
            continue # Skip this image if dimensions cannot be read


        annotations = parse_yolo_annotation(annotation_path, img_width, img_height, class_names)
        for ann in annotations:
            ann['image_filename'] = image_file
            ann['split'] = split
            all_annotations.append(ann)


# Create a pandas DataFrame from the collected annotations
annotations_df = pd.DataFrame(all_annotations)

# Display the first few rows of the DataFrame
display(annotations_df.head())

# Display some basic info about the DataFrame
print("\nDataFrame Info:")
annotations_df.info()

# Display the number of annotations per split, only if the DataFrame is not empty
if not annotations_df.empty:
    print("\nNumber of annotations per split:")
    print(annotations_df['split'].value_counts())

    # Display the number of annotations per class
    print("\nNumber of annotations per class:")
    print(annotations_df['class_name'].value_counts())
else:
    print("\nNo annotations found to display statistics.")
# Out:
# Warning: data.yaml not found. Class IDs will be used instead.
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
#
# No annotations found to display statistics.

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because the `data.yaml` file was not found and no annotation files (`.txt`) were found in the main split directories alongside the images. This suggests that the dataset format might not be a standard YOLO structure or that the annotation files have a different extension or naming convention. I need to re-verify the contents of the split directories more thoroughly. It's possible the annotation files are in a different format, like XML (VOC). I will modify the code to look for both `.txt` and `.xml` files and try to parse them. If `.xml` files are found, I will implement VOC parsing logic.

# %%
# Correcting the dataset directory path based on the initial download output
dataset_dir = 'garbage-detection-14'

# Function to parse YOLO annotation files
def parse_yolo_annotation(annotation_path, image_width, image_height, class_names):
    annotations = []
    if not os.path.exists(annotation_path):
        return annotations # Return empty list if file doesn't exist

    with open(annotation_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                 continue # Skip malformed line

            try:
                class_id = int(parts[0])
                center_x, center_y, width, height = map(float, parts[1:])
            except ValueError:
                 continue # Skip line with invalid format

            x_min = (center_x - width / 2) * image_width
            y_min = (center_y - height / 2) * image_height
            x_max = (center_x + width / 2) * image_width
            y_max = (center_y + height / 2) * image_height

            class_name = class_names[class_id] if class_id < len(class_names) else f'class_{class_id}'

            annotations.append({
                'class_id': class_id,
                'class_name': class_name,
                'x_min': x_min,
                'y_min': y_min,
                'x_max': x_max,
                'y_max': y_max
            })
    return annotations

# Function to parse VOC XML annotation files
def parse_voc_annotation(annotation_path, class_names):
    annotations = []
    if not os.path.exists(annotation_path):
        return annotations # Return empty list if file doesn't exist

    try:
        tree = ET.parse(annotation_path)
        root = tree.getroot()

        size = root.find('size')
        image_width = int(size.find('width').text)
        image_height = int(size.find('height').text)

        for obj in root.findall('object'):
            class_name = obj.find('name').text
            # Find class_id from class_names, if available. Otherwise, use a placeholder or skip.
            try:
                class_id = class_names.index(class_name) if class_name in class_names else -1 # Use -1 if class_name not in list
            except ValueError:
                 class_id = -1 # Handle case where class_names might be empty or not a list

            bndbox = obj.find('bndbox')
            x_min = float(bndbox.find('xmin').text)
            y_min = float(bndbox.find('ymin').text)
            x_max = float(bndbox.find('xmax').text)
            y_max = float(bndbox.find('ymax').text)

            annotations.append({
                'class_id': class_id,
                'class_name': class_name,
                'x_min': x_min,
                'y_min': y_min,
                'x_max': x_max,
                'y_max': y_max,
                'image_width': image_width,
                'image_height': image_height
            })
    except Exception as e:
        print(f"Error parsing XML file {annotation_path}: {e}")
        return [] # Return empty list on error

    return annotations


# Read class names from data.yaml (if exists)
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
class_names = []
if os.path.exists(data_yaml_path):
    with open(data_yaml_path, 'r') as f:
        data_yaml = yaml.safe_load(f)
        class_names = data_yaml.get('names', [])
        if class_names:
            print(f"Class names loaded from data.yaml: {class_names}")
        else:
             print("Warning: 'names' not found in data.yaml. Will try to infer from annotations or use IDs.")
    # If data.yaml exists but names are missing, don't create dummy names yet,
    # as VOC parsing will give class names directly.
else:
    print("Warning: data.yaml not found. Will try to infer class names from annotations or use IDs.")
    # No class names initially if data.yaml is missing and not VOC

all_annotations = []
splits = ['train', 'valid', 'test']

for split in splits:
    split_dir = os.path.join(dataset_dir, split)

    if not os.path.exists(split_dir):
        print(f"Split directory not found: {split_dir}")
        continue

    files_in_split = os.listdir(split_dir)
    image_files = [f for f in files_in_split if f.endswith(('.jpg', '.jpeg', '.png'))]
    annotation_files_txt = {os.path.splitext(f)[0]: f for f in files_in_split if f.endswith('.txt')}
    annotation_files_xml = {os.path.splitext(f)[0]: f for f in files_in_split if f.endswith('.xml')}


    for image_file in image_files:
        base_name = os.path.splitext(image_file)[0]

        annotations = []
        img_width, img_height = 0, 0

        # Try parsing YOLO (.txt) annotations first
        if base_name in annotation_files_txt:
            annotation_path = os.path.join(split_dir, annotation_files_txt[base_name])
             # Get image dimensions for YOLO parsing
            image_path = os.path.join(split_dir, image_file)
            try:
                with Image.open(image_path) as img:
                    img_width, img_height = img.size
            except Exception as e:
                print(f"Could not read image dimensions for {image_path}: {e}")
                continue # Skip this image if dimensions cannot be read

            # Ensure class_names is populated for YOLO parsing if data.yaml was missing/empty
            if not class_names:
                print("Inferring class names from YOLO IDs (assuming 100 potential classes).")
                class_names = [f'class_{i}' for i in range(100)] # Fallback dummy names

            annotations = parse_yolo_annotation(annotation_path, img_width, img_height, class_names)

        # If no YOLO annotations found, try parsing VOC (.xml) annotations
        elif base_name in annotation_files_xml:
            annotation_path = os.path.join(split_dir, annotation_files_xml[base_name])
            annotations = parse_voc_annotation(annotation_path, class_names)
            # For VOC, image dimensions are usually in the XML, but we'll get them from the image as well for consistency/verification
            if annotations: # If parsing was successful, get dimensions from one annotation or image
                 img_width = annotations[0].get('image_width', 0)
                 img_height = annotations[0].get('image_height', 0)
                 if img_width == 0 or img_height == 0: # If not in XML, read from image
                     image_path = os.path.join(split_dir, image_file)
                     try:
                         with Image.open(image_path) as img:
                             img_width, img_height = img.size
                     except Exception as e:
                         print(f"Could not read image dimensions for {image_path}: {e}")
                         # If dimensions can't be read, and not in XML, these annotations are likely unusable
                         print(f"Warning: Could not get image dimensions for VOC annotations in {annotation_path}. Skipping annotations.")
                         annotations = [] # Clear annotations if dimensions are critical and missing

            # If class_names was empty and VOC annotations were found, populate class_names from found names
            if not class_names and annotations:
                 print("Inferring class names from VOC annotation names.")
                 # Collect unique class names found in this split's annotations
                 found_voc_names = list(set([ann['class_name'] for ann in annotations if 'class_name' in ann]))
                 # This approach only gets names from current split; a better approach would collect from all splits
                 # For simplicity here, we'll just use the names found.
                 # If we need class_ids later that map to a consistent list, we'd need a different approach.
                 # For now, class_id might be -1 if not found in data.yaml.
                 pass # Class names are directly in the annotations, so no need to map IDs if data.yaml was missing


        # Add found annotations to the list
        for ann in annotations:
            # Add image dimensions to DataFrame if they weren't already added by VOC parser
            if 'image_width' not in ann:
                 ann['image_width'] = img_width
            if 'image_height' not in ann:
                 ann['image_height'] = img_height

            ann['image_filename'] = image_file
            ann['split'] = split
            all_annotations.append(ann)


# Create a pandas DataFrame from the collected annotations
annotations_df = pd.DataFrame(all_annotations)

# Ensure class_name is present even if data.yaml was missing and no VOC names inferred
if 'class_name' not in annotations_df.columns and 'class_id' in annotations_df.columns:
    # If class_name is missing but class_id is there, create class names from IDs as a fallback
     annotations_df['class_name'] = annotations_df['class_id'].apply(lambda x: class_names[x] if x < len(class_names) and x >= 0 else f'class_{x}')


# Display the first few rows of the DataFrame
display(annotations_df.head())

# Display some basic info about the DataFrame
print("\nDataFrame Info:")
annotations_df.info()

# Display the number of annotations per split, only if the DataFrame is not empty
if not annotations_df.empty:
    print("\nNumber of annotations per split:")
    print(annotations_df['split'].value_counts())

    # Display the number of annotations per class
    print("\nNumber of annotations per class:")
    print(annotations_df['class_name'].value_counts())

    # Display summary statistics for bounding box coordinates
    print("\nBounding Box Coordinate Statistics:")
    display(annotations_df[['x_min', 'y_min', 'x_max', 'y_max']].describe())

else:
    print("\nNo annotations found to display statistics.")
# Out:
# Warning: data.yaml not found. Will try to infer class names from annotations or use IDs.
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
#
# No annotations found to display statistics.

# %% [markdown]
# **Reasoning**:
# The previous attempts to find and parse annotations failed, resulting in an empty DataFrame. This indicates that neither standard YOLO `.txt` files nor standard VOC `.xml` files are present directly in the split directories alongside the images, nor in `images`/`labels` subdirectories. However, the previous successful step showed a flat structure within `garbage-detection-14/train` etc., listing both image files and `.txt` files (which were incorrectly assumed to be annotations before). It's possible the `.txt` files listed are indeed the annotations, but there was an issue in the parsing logic or file lookup. I need to re-examine the initial file listing carefully and ensure the file path logic is correct for accessing these `.txt` files directly in the split directories. I will also print the paths being checked to diagnose why files are not being found.

# %%
# Correcting the dataset directory path based on the initial download output
dataset_dir = 'garbage-detection-14'

# Function to parse YOLO annotation files
def parse_yolo_annotation(annotation_path, image_width, image_height, class_names):
    annotations = []
    if not os.path.exists(annotation_path):
        # print(f"Annotation file not found: {annotation_path}") # Keep this commented unless debugging
        return annotations # Return empty list if file doesn't exist

    with open(annotation_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                 # print(f"Skipping malformed annotation line in {annotation_path}: {line.strip()}")
                 continue # Skip malformed line

            try:
                class_id = int(parts[0])
                center_x, center_y, width, height = map(float, parts[1:])
            except ValueError:
                 # print(f"Skipping line with invalid format in {annotation_path}: {line.strip()}")
                 continue # Skip line with invalid format

            x_min = (center_x - width / 2) * image_width
            y_min = (center_y - height / 2) * image_height
            x_max = (center_x + width / 2) * image_width
            y_max = (center_y + height / 2) * image_height

            class_name = class_names[class_id] if 0 <= class_id < len(class_names) else f'class_{class_id}'

            annotations.append({
                'class_id': class_id,
                'class_name': class_name,
                'x_min': x_min,
                'y_min': y_min,
                'x_max': x_max,
                'y_max': y_max
            })
    return annotations


# Read class names from data.yaml (if exists)
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
class_names = []
if os.path.exists(data_yaml_path):
    with open(data_yaml_path, 'r') as f:
        data_yaml = yaml.safe_load(f)
        class_names = data_yaml.get('names', [])
        if class_names:
            print(f"Class names loaded from data.yaml: {class_names}")
        else:
             print("Warning: 'names' not found in data.yaml. Will use IDs.")
    # If data.yaml exists but names are missing, use generic names based on IDs
    if not class_names:
         class_names = [f'class_{i}' for i in range(100)] # Fallback dummy names
else:
    print("Warning: data.yaml not found. Will use IDs.")
    # If data.yaml is missing, create dummy class names
    class_names = [f'class_{i}' for i in range(100)] # Fallback dummy names


all_annotations = []
splits = ['train', 'valid', 'test']

for split in splits:
    split_dir = os.path.join(dataset_dir, split)

    if not os.path.exists(split_dir):
        print(f"Split directory not found: {split_dir}")
        continue

    files_in_split = os.listdir(split_dir)
    image_files = [f for f in files_in_split if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    annotation_files_txt = {os.path.splitext(f)[0]: f for f in files_in_split if f.lower().endswith('.txt')}


    print(f"\nProcessing split: {split}")
    print(f"Found {len(image_files)} image files and {len(annotation_files_txt)} potential .txt annotation files.")


    for image_file in image_files:
        base_name = os.path.splitext(image_file)[0]
        annotation_file_name = base_name + '.txt'
        annotation_path = os.path.join(split_dir, annotation_file_name)

        # print(f"Checking for annotation file: {annotation_path}") # Debugging line

        if os.path.exists(annotation_path):
             # Get image dimensions for YOLO parsing
            image_path = os.path.join(split_dir, image_file)
            img_width, img_height = 0, 0
            try:
                with Image.open(image_path) as img:
                    img_width, img_height = img.size
            except Exception as e:
                print(f"Could not read image dimensions for {image_path}: {e}")
                continue # Skip this image if dimensions cannot be read

            annotations = parse_yolo_annotation(annotation_path, img_width, img_height, class_names)

            for ann in annotations:
                ann['image_filename'] = image_file
                ann['split'] = split
                ann['image_width'] = img_width
                ann['image_height'] = img_height
                all_annotations.append(ann)
        # else:
            # print(f"Annotation file not found for image: {image_file}") # Keep this commented unless debugging


# Create a pandas DataFrame from the collected annotations
annotations_df = pd.DataFrame(all_annotations)

# Display the first few rows of the DataFrame
display(annotations_df.head())

# Display some basic info about the DataFrame
print("\nDataFrame Info:")
annotations_df.info()

# Display the number of annotations per split, only if the DataFrame is not empty
if not annotations_df.empty:
    print("\nNumber of annotations per split:")
    print(annotations_df['split'].value_counts())

    # Display the number of annotations per class
    print("\nNumber of annotations per class:")
    print(annotations_df['class_name'].value_counts())

    # Display summary statistics for bounding box coordinates
    print("\nBounding Box Coordinate Statistics:")
    display(annotations_df[['x_min', 'y_min', 'x_max', 'y_max']].describe())

else:
    print("\nNo annotations found to display statistics.")
# Out:
# Warning: data.yaml not found. Will use IDs.
#
# Processing split: train
# Found 1365 image files and 0 potential .txt annotation files.
#
# Processing split: valid
# Found 315 image files and 0 potential .txt annotation files.
#
# Processing split: test
# Found 184 image files and 0 potential .txt annotation files.
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
#
# No annotations found to display statistics.

# %% [markdown]
# ## Explore the data
#
# ### Subtask:
# Explore the data to understand its structure and content.

# %% [markdown]
# ## Load the dataset retry 1
#
# ### Subtask:
# Load the dataset into a suitable format for analysis, such as a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# The previous attempts to load the data failed because the annotation files were not found. I will try one more time to load the data into a pandas DataFrame, ensuring the paths are correct and handling potential issues with file listing and reading. I will include debugging prints to confirm the paths being checked.

# %%
import os
import pandas as pd
from PIL import Image
import yaml

# Correcting the dataset directory path based on the initial download output
dataset_dir = 'garbage-detection-14'

# Function to parse YOLO annotation files
def parse_yolo_annotation(annotation_path, image_width, image_height, class_names):
    annotations = []
    if not os.path.exists(annotation_path):
        # print(f"Annotation file not found: {annotation_path}") # Keep this commented unless debugging
        return annotations # Return empty list if file doesn't exist

    with open(annotation_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                 # print(f"Skipping malformed annotation line in {annotation_path}: {line.strip()}")
                 continue # Skip malformed line

            try:
                class_id = int(parts[0])
                center_x, center_y, width, height = map(float, parts[1:])
            except ValueError:
                 # print(f"Skipping line with invalid format in {annotation_path}: {line.strip()}")
                 continue # Skip line with invalid format

            x_min = (center_x - width / 2) * image_width
            y_min = (center_y - height / 2) * image_height
            x_max = (center_x + width / 2) * image_width
            y_max = (center_y + height / 2) * image_height

            class_name = class_names[class_id] if 0 <= class_id < len(class_names) else f'class_{class_id}'

            annotations.append({
                'class_id': class_id,
                'class_name': class_name,
                'x_min': x_min,
                'y_min': y_min,
                'x_max': x_max,
                'y_max': y_max
            })
    return annotations


# Read class names from data.yaml (if exists)
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
class_names = []
if os.path.exists(data_yaml_path):
    with open(data_yaml_path, 'r') as f:
        data_yaml = yaml.safe_load(f)
        class_names = data_yaml.get('names', [])
        if class_names:
            print(f"Class names loaded from data.yaml: {class_names}")
        else:
             print("Warning: 'names' not found in data.yaml. Will use IDs.")
    # If data.yaml exists but names are missing, use generic names based on IDs
    if not class_names:
         class_names = [f'class_{i}' for i in range(100)] # Fallback dummy names
else:
    print("Warning: data.yaml not found. Will use IDs.")
    # If data.yaml is missing, create dummy class names
    class_names = [f'class_{i}' for i in range(100)] # Fallback dummy names


all_annotations = []
splits = ['train', 'valid', 'test']

for split in splits:
    split_dir = os.path.join(dataset_dir, split)

    if not os.path.exists(split_dir):
        print(f"Split directory not found: {split_dir}")
        continue

    # Check for 'images' and 'labels' subdirectories, common in YOLO
    image_dir = os.path.join(split_dir, 'images')
    label_dir = os.path.join(split_dir, 'labels')

    if not os.path.exists(image_dir) or not os.path.exists(label_dir):
        print(f"Warning: 'images' or 'labels' subdirectory not found in {split_dir}. Trying root split directory.")
        image_dir = split_dir
        label_dir = split_dir

    if not os.path.exists(image_dir):
         print(f"Error: Image directory not found at {image_dir}. Skipping split.")
         continue
    if not os.path.exists(label_dir):
        print(f"Error: Label directory not found at {label_dir}. Skipping split.")
        continue


    files_in_image_dir = os.listdir(image_dir)
    image_files = [f for f in files_in_image_dir if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    annotation_files_txt = {os.path.splitext(f)[0]: f for f in os.listdir(label_dir) if f.lower().endswith('.txt')}


    print(f"\nProcessing split: {split}")
    print(f"Found {len(image_files)} image files in {image_dir} and {len(annotation_files_txt)} potential .txt annotation files in {label_dir}.")


    for image_file in image_files:
        base_name = os.path.splitext(image_file)[0]
        annotation_file_name = base_name + '.txt'
        annotation_path = os.path.join(label_dir, annotation_file_name)
        image_path = os.path.join(image_dir, image_file)

        # print(f"Checking for annotation file: {annotation_path}") # Debugging line

        if os.path.exists(annotation_path):
             # Get image dimensions for YOLO parsing
            img_width, img_height = 0, 0
            try:
                with Image.open(image_path) as img:
                    img_width, img_height = img.size
            except Exception as e:
                print(f"Could not read image dimensions for {image_path}: {e}")
                continue # Skip this image if dimensions cannot be read

            annotations = parse_yolo_annotation(annotation_path, img_width, img_height, class_names)

            for ann in annotations:
                ann['image_filename'] = image_file
                ann['split'] = split
                ann['image_width'] = img_width
                ann['image_height'] = img_height
                all_annotations.append(ann)
        # else:
            # print(f"Annotation file not found for image: {image_file} at {annotation_path}") # Keep this commented unless debugging


# Create a pandas DataFrame from the collected annotations
annotations_df = pd.DataFrame(all_annotations)

# Display the first few rows of the DataFrame
display(annotations_df.head())

# Display some basic info about the DataFrame
print("\nDataFrame Info:")
annotations_df.info()

# Display the number of annotations per split, only if the DataFrame is not empty
if not annotations_df.empty:
    print("\nNumber of annotations per split:")
    print(annotations_df['split'].value_counts())

    # Display the number of annotations per class
    print("\nNumber of annotations per class:")
    print(annotations_df['class_name'].value_counts())

    # Display summary statistics for bounding box coordinates
    print("\nBounding Box Coordinate Statistics:")
    display(annotations_df[['x_min', 'y_min', 'x_max', 'y_max']].describe())

else:
    print("\nNo annotations found to display statistics.")
# Out:
# Warning: data.yaml not found. Will use IDs.
# Warning: 'images' or 'labels' subdirectory not found in garbage-detection-14/train. Trying root split directory.
#
# Processing split: train
# Found 1365 image files in garbage-detection-14/train and 0 potential .txt annotation files in garbage-detection-14/train.
# Warning: 'images' or 'labels' subdirectory not found in garbage-detection-14/valid. Trying root split directory.
#
# Processing split: valid
# Found 315 image files in garbage-detection-14/valid and 0 potential .txt annotation files in garbage-detection-14/valid.
# Warning: 'images' or 'labels' subdirectory not found in garbage-detection-14/test. Trying root split directory.
#
# Processing split: test
# Found 184 image files in garbage-detection-14/test and 0 potential .txt annotation files in garbage-detection-14/test.
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
#
# No annotations found to display statistics.

# %% [markdown]
# ## Explore the data
#
# ### Subtask:
# Explore the data to understand its structure and content.

# %% [markdown]
# **Reasoning**:
# Check if the annotations_df DataFrame is empty and proceed with exploration steps if it's not empty, as per the instructions.

# %%
if annotations_df.empty:
    print("The annotations_df DataFrame is empty. Data could not be loaded, and exploration cannot proceed.")
else:
    # Display the first 5 rows
    print("First 5 rows of the DataFrame:")
    display(annotations_df.head())

    # Print concise summary
    print("\nDataFrame Info:")
    annotations_df.info()

    # Print number of unique images
    num_unique_images = annotations_df['image_filename'].nunique()
    print(f"\nNumber of unique images: {num_unique_images}")

    # Print total number of annotations
    total_annotations = len(annotations_df)
    print(f"Total number of annotations: {total_annotations}")

    # List unique class names
    unique_classes = annotations_df['class_name'].unique()
    print(f"\nUnique class names: {list(unique_classes)}")
# Out:
# The annotations_df DataFrame is empty. Data could not be loaded, and exploration cannot proceed.

# %% [markdown]
# ## Load the dataset retry 2
#
# ### Subtask:
# Load the dataset into a suitable format for analysis, such as a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# The previous attempts to load the data failed because the annotation files were not found in the expected locations or formats. I need to re-examine the directory structure again to make sure I am looking in the correct place and for the correct file types. I will add more explicit print statements to verify the paths being checked and the files being found at each step. I will also ensure robust error handling for file reading and parsing.

# %%
import os
import pandas as pd
from PIL import Image
import yaml
import xml.etree.ElementTree as ET

# Correcting the dataset directory path based on the initial download output
dataset_dir = 'garbage-detection-14'

# --- Debugging: Inspect Directory Structure ---
print(f"Inspecting directory: {dataset_dir}")
if os.path.exists(dataset_dir):
    print(f"Contents of {dataset_dir}: {os.listdir(dataset_dir)}")
    for split in ['train', 'valid', 'test']:
        split_path = os.path.join(dataset_dir, split)
        if os.path.exists(split_path):
            print(f"Contents of {split_path}: {os.listdir(split_path)[:10]}...") # Print first 10 items
            # Check for subdirectories like 'images' and 'labels'
            if os.path.exists(os.path.join(split_path, 'images')):
                print(f"  Found 'images' subdirectory in {split_path}")
            if os.path.exists(os.path.join(split_path, 'labels')):
                print(f"  Found 'labels' subdirectory in {split_path}")
        else:
            print(f"Split directory not found: {split_path}")
else:
    print(f"Dataset directory not found: {dataset_dir}")
    # If dataset_dir doesn't exist, the whole process will fail.
    # Set annotations_df to empty and finish the task.
    annotations_df = pd.DataFrame()
    print("\nDataset directory not found. Cannot proceed with loading.")
    # Skip the rest of the loading logic and proceed to the final check.


# --- Function to parse YOLO annotation files ---
def parse_yolo_annotation(annotation_path, image_width, image_height, class_names):
    annotations = []
    if not os.path.exists(annotation_path):
        # print(f"Annotation file not found (YOLO): {annotation_path}") # Debugging line
        return annotations # Return empty list if file doesn't exist

    try:
        with open(annotation_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 5:
                     print(f"Skipping malformed YOLO annotation line in {annotation_path}: {line.strip()}")
                     continue # Skip malformed line

                try:
                    class_id = int(parts[0])
                    center_x, center_y, width, height = map(float, parts[1:])
                except ValueError:
                     print(f"Skipping YOLO line with invalid format in {annotation_path}: {line.strip()}")
                     continue # Skip line with invalid format

                # Convert to x_min, y_min, x_max, y_max (absolute)
                x_min = (center_x - width / 2) * image_width
                y_min = (center_y - height / 2) * image_height
                x_max = (center_x + width / 2) * image_width
                y_max = (center_y + height / 2) * image_height

                class_name = class_names[class_id] if 0 <= class_id < len(class_names) else f'class_{class_id}'

                annotations.append({
                    'class_id': class_id,
                    'class_name': class_name,
                    'x_min': x_min,
                    'y_min': y_min,
                    'x_max': x_max,
                    'y_max': y_max,
                    'image_width': image_width, # Add dimensions here
                    'image_height': image_height # Add dimensions here
                })
    except Exception as e:
        print(f"Error reading or parsing YOLO file {annotation_path}: {e}")
        return [] # Return empty list on error

    return annotations

# --- Function to parse VOC XML annotation files ---
def parse_voc_annotation(annotation_path, class_names):
    annotations = []
    if not os.path.exists(annotation_path):
        # print(f"Annotation file not found (VOC): {annotation_path}") # Debugging line
        return annotations # Return empty list if file doesn't exist

    try:
        tree = ET.parse(annotation_path)
        root = tree.getroot()

        size = root.find('size')
        if size is None:
             print(f"Warning: Size element not found in XML file {annotation_path}. Skipping.")
             return [] # Cannot parse without size

        image_width = int(size.find('width').text)
        image_height = int(size.find('height').text)

        for obj in root.findall('object'):
            name_element = obj.find('name')
            if name_element is None:
                 print(f"Warning: Object name not found in XML file {annotation_path}. Skipping object.")
                 continue
            class_name = name_element.text

            # Find class_id from class_names, if available. Otherwise, use a placeholder or -1.
            class_id = -1 # Default to -1 if not found
            if class_names:
                try:
                    class_id = class_names.index(class_name)
                except ValueError:
                     # Class name not in the provided class_names list
                     pass # class_id remains -1

            bndbox = obj.find('bndbox')
            if bndbox is None:
                 print(f"Warning: Bndbox element not found for an object in XML file {annotation_path}. Skipping object.")
                 continue

            xmin_elem = bndbox.find('xmin')
            ymin_elem = bndbox.find('ymin')
            xmax_elem = bndbox.find('xmax')
            ymax_elem = bndbox.find('ymax')

            if None in [xmin_elem, ymin_elem, xmax_elem, ymax_elem]:
                 print(f"Warning: Missing bounding box coordinates for an object in XML file {annotation_path}. Skipping object.")
                 continue

            try:
                x_min = float(xmin_elem.text)
                y_min = float(ymin_elem.text)
                x_max = float(xmax_elem.text)
                y_max = float(ymax_elem.text)
            except ValueError:
                 print(f"Warning: Invalid bounding box coordinate format in XML file {annotation_path}. Skipping object.")
                 continue


            annotations.append({
                'class_id': class_id, # Will be -1 if class_name not in class_names
                'class_name': class_name,
                'x_min': x_min,
                'y_min': y_min,
                'x_max': x_max,
                'y_max': y_max,
                'image_width': image_width, # Add dimensions here
                'image_height': image_height # Add dimensions here
            })
    except Exception as e:
        print(f"Error reading or parsing XML file {annotation_path}: {e}")
        return [] # Return empty list on error

    return annotations


# --- Read class names from data.yaml (if exists) ---
class_names = []
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
if os.path.exists(data_yaml_path):
    print(f"\nFound data.yaml at: {data_yaml_path}")
    try:
        with open(data_yaml_path, 'r') as f:
            data_yaml = yaml.safe_load(f)
            class_names = data_yaml.get('names', [])
            if class_names:
                print(f"Class names loaded from data.yaml: {class_names}")
            else:
                 print("Warning: 'names' not found or is empty in data.yaml. Will try to infer from annotations or use IDs.")
    except Exception as e:
        print(f"Error reading data.yaml: {e}")
        print("Will try to infer class names from annotations or use IDs.")
else:
    print("\ndata.yaml not found. Will try to infer class names from annotations or use IDs.")


# --- Collect Annotations ---
all_annotations = []
splits = ['train', 'valid', 'test']

# Keep track of inferred class names if data.yaml was missing or empty
inferred_class_names = set()

if os.path.exists(dataset_dir): # Only proceed if dataset_dir exists
    for split in splits:
        split_dir = os.path.join(dataset_dir, split)

        if not os.path.exists(split_dir):
            print(f"Split directory not found: {split_dir}. Skipping.")
            continue

        # Determine image and label directories - check common structures
        image_dir = os.path.join(split_dir, 'images')
        label_dir = os.path.join(split_dir, 'labels')

        if not os.path.exists(image_dir) or not os.path.exists(label_dir):
            print(f"Info: 'images' or 'labels' subdirectory not found in {split_dir}. Checking root split directory.")
            image_dir = split_dir
            label_dir = split_dir

        if not os.path.exists(image_dir):
             print(f"Error: Image directory not found at {image_dir}. Skipping split {split}.")
             continue
        if not os.path.exists(label_dir):
            print(f"Error: Label directory not found at {label_dir}. Skipping split {split}.")
            continue


        files_in_image_dir = []
        if os.path.exists(image_dir):
             files_in_image_dir = os.listdir(image_dir)
        image_files = [f for f in files_in_image_dir if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

        files_in_label_dir = []
        if os.path.exists(label_dir):
             files_in_label_dir = os.listdir(label_dir)
        annotation_files_txt = {os.path.splitext(f)[0]: f for f in files_in_label_dir if f.lower().endswith('.txt')}
        annotation_files_xml = {os.path.splitext(f)[0]: f for f in files_in_label_dir if f.lower().endswith('.xml')}


        print(f"\nProcessing split: {split}")
        print(f"  Image directory: {image_dir}, found {len(image_files)} image files.")
        print(f"  Label directory: {label_dir}, found {len(annotation_files_txt)} .txt files and {len(annotation_files_xml)} .xml files.")


        for image_file in image_files:
            base_name = os.path.splitext(image_file)[0]
            image_path = os.path.join(image_dir, image_file)

            annotations = []
            img_width, img_height = 0, 0

            # Attempt to read image dimensions first
            try:
                with Image.open(image_path) as img:
                    img_width, img_height = img.size
            except Exception as e:
                print(f"Could not read image dimensions for {image_path}: {e}. Skipping image.")
                continue # Skip this image if dimensions cannot be read

            # Try parsing YOLO (.txt) annotations
            if base_name in annotation_files_txt:
                annotation_file_name = annotation_files_txt[base_name]
                annotation_path = os.path.join(label_dir, annotation_file_name)
                # print(f"  Attempting to parse YOLO: {annotation_path}") # Debugging line
                # Use class_names from data.yaml if available, otherwise YOLO parser uses IDs
                annotations = parse_yolo_annotation(annotation_path, img_width, img_height, class_names if class_names else [f'class_{i}' for i in range(100)]) # Fallback names for YOLO if data.yaml empty/missing

            # If no YOLO annotations found for this image, try parsing VOC (.xml) annotations
            elif base_name in annotation_files_xml:
                annotation_file_name = annotation_files_xml[base_name]
                annotation_path = os.path.join(label_dir, annotation_file_name)
                # print(f"  Attempting to parse VOC: {annotation_path}") # Debugging line
                annotations = parse_voc_annotation(annotation_path, class_names) # VOC parser uses class_names list to find IDs

            # Add found annotations to the list
            for ann in annotations:
                # Ensure dimensions are present (should be added by parsers, but double check)
                if 'image_width' not in ann or 'image_height' not in ann:
                     ann['image_width'] = img_width
                     ann['image_height'] = img_height

                ann['image_filename'] = image_file
                ann['split'] = split
                all_annotations.append(ann)

                # Collect class names if data.yaml was missing/empty
                if not class_names and 'class_name' in ann:
                     inferred_class_names.add(ann['class_name'])


# Create a pandas DataFrame from the collected annotations
annotations_df = pd.DataFrame(all_annotations)

# If class_names was empty, populate it from inferred names for better reporting
if not class_names and inferred_class_names:
     class_names = sorted(list(inferred_class_names))
     print(f"\nInferred class names from annotations: {class_names}")
     # Update class_id for VOC annotations if they were added with class_id = -1
     if 'class_id' in annotations_df.columns:
         annotations_df['class_id'] = annotations_df['class_name'].apply(lambda name: class_names.index(name) if name in class_names else -1)


# --- Display Results ---
print("\n--- Annotation Loading Summary ---")

# Display the first few rows of the DataFrame
display(annotations_df.head())

# Display some basic info about the DataFrame
print("\nDataFrame Info:")
annotations_df.info()

# Display the number of annotations per split, only if the DataFrame is not empty
if not annotations_df.empty:
    print("\nNumber of annotations per split:")
    print(annotations_df['split'].value_counts())

    # Display the number of annotations per class
    print("\nNumber of annotations per class:")
    print(annotations_df['class_name'].value_counts())

    # Display summary statistics for bounding box coordinates
    print("\nBounding Box Coordinate Statistics:")
    display(annotations_df[['x_min', 'y_min', 'x_max', 'y_max', 'image_width', 'image_height']].describe())

else:
    print("\nNo annotations found to display statistics.")
    print("Please check the dataset directory structure and annotation file formats.")
# Out:
# Inspecting directory: garbage-detection-14
# Contents of garbage-detection-14: ['train', 'valid', 'README.dataset.txt', 'README.roboflow.txt', 'test']
# Contents of garbage-detection-14/train: ['929a16f0-R_1121_jpg.rf.2cb7c158ec86704ec06dc83bccbf35c4.jpg', 'Metal_522_jpg.rf.93481ac49a7ee9b3e52ad1c3aee2ad89.jpg', '5e179e44-R_124_jpg.rf.6411f513560e04588798934206144feb.jpg', 'glass501_jpg.rf.66d6fc358ca4e82acfb182b8c97c7b16.jpg', '15WJGM52A0NZ_jpg.rf.e99547634954f4772b5779df7a350775.jpg', 'Cup_Glass368_jpg.rf.d7683fbadd63fae82c54eb5154cccb70.jpg', 'Metal_524_jpg.rf.e3ea149c3cbac729e3262200430437f1.jpg', 'glass43_jpg.rf.65dfced2bd06a0cd65c5f0a6c586dce3.jpg', 'Cup_Glass076_jpg.rf.6a8d47c024bc984cdcbc9f90c2aea0c4.jpg', 'metal593_jpg.rf.77f46166ce48e9ecc2cdd7ad7031972c.jpg']...
# Contents of garbage-detection-14/valid: ['R_5205_jpg.rf.e4843929edf42be2f66026957c8a9490.jpg', 'Metal_37_jpg.rf.848fc54f1eaee1de5534ac1db4d11bbd.jpg', 'cf95e304-R_1407_jpg.rf.4da1a25d92ee0efac71cf2fe945e1e9a.jpg', 'a51902e0-R_64_jpg.rf.0c1dafd5fd195e31b4a71a72285750c3.jpg', '64VUFNVXK9TU_jpg.rf.e9e28ec3f78069d822718faa649ce0c0.jpg', 'R_5058_jpg.rf.9ff1b9337231c8eca09856451e92486a.jpg', 'Cup_Glass298_jpg.rf.2a5874697e8dae39edf05156c98d9d49.jpg', '54WJW8COSWYU_jpg.rf.203451d50c7f154764497e5e612096ae.jpg', '19f1be33-R_1427_jpg.rf.8b64eb7dca915844aa45eecb82a304fe.jpg', 'Metal_364_jpg.rf.9dac97a14abd03705a6d61c66b16e811.jpg']...
# Contents of garbage-detection-14/test: ['glass473_jpg.rf.92fcde92fbc5e2a58ae11b9a2728ba37.jpg', '89d2a416-R_1208_jpg.rf.0fe67e4849e9691d5d4faca2a513f6e4.jpg', '20221020_120352_jpg.rf.18183c250f35b062372fabb67daafa34.jpg', 'glass480_jpg.rf.8b0b977d41de01d15c02adc64abbcfbf.jpg', 'Cup_Glass231_jpg.rf.daf826f04462f1e61c2192f4b3b2baca.jpg', '20221020_123037_jpg.rf.34f29172f6d5cf8c51b18984b119766f.jpg', 'glass-428_jpg.rf.ff22b0cf5bee7c853721ea16c1fb341c.jpg', '1TBKD9FYTLU3_jpg.rf.0bfe1a101c823e5a7b34228c0844c6fe.jpg', 'glass234_jpg.rf.6896b300d0480fd2c77ded5169281d1b.jpg', 'glass415_jpg.rf.f4e7f34b30c7a6f7cfbfb585d5f34040.jpg']...
#
# data.yaml not found. Will try to infer class names from annotations or use IDs.
# Info: 'images' or 'labels' subdirectory not found in garbage-detection-14/train. Checking root split directory.
#
# Processing split: train
#   Image directory: garbage-detection-14/train, found 1365 image files.
#   Label directory: garbage-detection-14/train, found 0 .txt files and 0 .xml files.
# Info: 'images' or 'labels' subdirectory not found in garbage-detection-14/valid. Checking root split directory.
#
# Processing split: valid
#   Image directory: garbage-detection-14/valid, found 315 image files.
#   Label directory: garbage-detection-14/valid, found 0 .txt files and 0 .xml files.
# Info: 'images' or 'labels' subdirectory not found in garbage-detection-14/test. Checking root split directory.
#
# Processing split: test
#   Image directory: garbage-detection-14/test, found 184 image files.
#   Label directory: garbage-detection-14/test, found 0 .txt files and 0 .xml files.
#
# --- Annotation Loading Summary ---
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
#
# No annotations found to display statistics.
# Please check the dataset directory structure and annotation file formats.

# %% [markdown]
# **Reasoning**:
# The debugging output shows that `data.yaml` was not found, and no `.txt` or `.xml` annotation files were found in the split directories or in `images`/`labels` subdirectories. However, the initial `os.listdir` output for the train directory in the previous turn *did* show files like `929a16f0-R_1121_jpg.rf.2cb7c158ec86704ec06dc83bccbf35c4.jpg`. This indicates the files are there, but the code is not correctly identifying the annotation files. The filenames include `.jpg.rf.`, which might be the base name prefix for the corresponding `.txt` files. I need to refine the logic for matching image files to annotation files, considering this naming convention, and also double-check the `data.yaml` location again as the previous output is contradictory.

# %%
# Correcting the dataset directory path based on the initial download output
dataset_dir = 'garbage-detection-14'

# --- Re-check data.yaml location ---
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
class_names = []
if os.path.exists(data_yaml_path):
    print(f"\nFound data.yaml at: {data_yaml_path}")
    try:
        with open(data_yaml_path, 'r') as f:
            data_yaml = yaml.safe_load(f)
            class_names = data_yaml.get('names', [])
            if class_names:
                print(f"Class names loaded from data.yaml: {class_names}")
            else:
                 print("Warning: 'names' not found or is empty in data.yaml. Will try to infer from annotations or use IDs.")
    except Exception as e:
        print(f"Error reading data.yaml: {e}")
        print("Will try to infer class names from annotations or use IDs.")
else:
    print("\ndata.yaml not found. Will try to infer class names from annotations or use IDs.")


# --- Collect Annotations (Refined Logic for File Matching) ---
all_annotations = []
splits = ['train', 'valid', 'test']

# Keep track of inferred class names if data.yaml was missing or empty
inferred_class_names = set()

if os.path.exists(dataset_dir): # Only proceed if dataset_dir exists
    for split in splits:
        split_dir = os.path.join(dataset_dir, split)

        if not os.path.exists(split_dir):
            print(f"Split directory not found: {split_dir}. Skipping.")
            continue

        # Determine image and label directories - check common structures
        image_dir = os.path.join(split_dir, 'images')
        label_dir = os.path.join(split_dir, 'labels')

        # If 'images' or 'labels' don't exist, assume files are in the root split directory
        if not os.path.exists(image_dir) or not os.path.exists(label_dir):
            image_dir = split_dir
            label_dir = split_dir
            print(f"Info: Using root split directory for images and labels: {split_dir}")


        if not os.path.exists(image_dir):
             print(f"Error: Image directory not found at {image_dir}. Skipping split {split}.")
             continue
        if not os.path.exists(label_dir):
            print(f"Error: Label directory not found at {label_dir}. Skipping split {split}.")
            continue


        files_in_image_dir = []
        if os.path.exists(image_dir):
             files_in_image_dir = os.listdir(image_dir)
        image_files = [f for f in files_in_image_dir if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

        files_in_label_dir = []
        if os.path.exists(label_dir):
             files_in_label_dir = os.listdir(label_dir)
        annotation_files_txt = {os.path.splitext(f)[0]: f for f in files_in_label_dir if f.lower().endswith('.txt')}
        annotation_files_xml = {os.path.splitext(f)[0]: f for f in files_in_label_dir if f.lower().endswith('.xml')}


        print(f"\nProcessing split: {split}")
        print(f"  Image directory: {image_dir}, found {len(image_files)} image files.")
        print(f"  Label directory: {label_dir}, found {len(annotation_files_txt)} .txt files and {len(annotation_files_xml)} .xml files.")


        for image_file in image_files:
            # Refined base name extraction: remove all extensions including .jpg.rf.*
            base_name = image_file
            for ext in ['.jpg', '.jpeg', '.png']:
                if base_name.lower().endswith(ext):
                    base_name = base_name[:-len(ext)]
                    break
            # Remove potential .rf. part and subsequent hash if present
            rf_part_index = base_name.lower().find('.rf.')
            if rf_part_index != -1:
                 base_name = base_name[:rf_part_index]


            image_path = os.path.join(image_dir, image_file)

            annotations = []
            img_width, img_height = 0, 0

            # Attempt to read image dimensions first (needed for YOLO)
            try:
                with Image.open(image_path) as img:
                    img_width, img_height = img.size
            except Exception as e:
                print(f"Could not read image dimensions for {image_path}: {e}. Skipping image.")
                continue # Skip this image if dimensions cannot be read

            # Try parsing YOLO (.txt) annotations - look for base_name + .txt
            annotation_file_name_txt = base_name + '.txt'
            annotation_path_txt = os.path.join(label_dir, annotation_file_name_txt)

            if os.path.exists(annotation_path_txt):
                # print(f"  Attempting to parse YOLO: {annotation_path_txt}") # Debugging line
                # Use class_names from data.yaml if available, otherwise YOLO parser uses IDs
                annotations = parse_yolo_annotation(annotation_path_txt, img_width, img_height, class_names if class_names else [f'class_{i}' for i in range(100)]) # Fallback names for YOLO if data.yaml empty/missing

            # If no YOLO annotations found for this image base name, try parsing VOC (.xml)
            # Note: VOC files might have a different naming convention or be less common
            # We'll still check based on the cleaned base_name + .xml
            elif base_name in annotation_files_xml: # Check if a matching XML exists
                 annotation_file_name_xml = annotation_files_xml[base_name]
                 annotation_path_xml = os.path.join(label_dir, annotation_file_name_xml)
                 print(f"  Attempting to parse VOC: {annotation_path_xml}") # Debugging line
                 annotations = parse_voc_annotation(annotation_path_xml, class_names) # VOC parser uses class_names list to find IDs
                 # For VOC, image dimensions might be in XML, but we already read them from the image above.

            # Add found annotations to the list
            for ann in annotations:
                # Ensure dimensions are present (should be added by parsers, but double check)
                if 'image_width' not in ann or 'image_height' not in ann:
                     ann['image_width'] = img_width
                     ann['image_height'] = img_height

                ann['image_filename'] = image_file # Store the original image filename
                ann['split'] = split
                all_annotations.append(ann)

                # Collect class names if data.yaml was missing/empty
                if not class_names and 'class_name' in ann:
                     inferred_class_names.add(ann['class_name'])


# Create a pandas DataFrame from the collected annotations
annotations_df = pd.DataFrame(all_annotations)

# If class_names was empty, populate it from inferred names for better reporting
if not class_names and inferred_class_names:
     class_names = sorted(list(inferred_class_names))
     print(f"\nInferred class names from annotations: {class_names}")
     # Update class_id for annotations if they were added with class_id = -1
     if 'class_id' in annotations_df.columns:
         annotations_df['class_id'] = annotations_df['class_name'].apply(lambda name: class_names.index(name) if name in class_names else -1)


# --- Display Results ---
print("\n--- Annotation Loading Summary ---")

# Display the first few rows of the DataFrame
display(annotations_df.head())

# Display some basic info about the DataFrame
print("\nDataFrame Info:")
annotations_df.info()

# Display the number of annotations per split, only if the DataFrame is not empty
if not annotations_df.empty:
    print("\nNumber of annotations per split:")
    print(annotations_df['split'].value_counts())

    # Display the number of annotations per class
    print("\nNumber of annotations per class:")
    print(annotations_df['class_name'].value_counts())

    # Display summary statistics for bounding box coordinates
    print("\nBounding Box Coordinate Statistics:")
    display(annotations_df[['x_min', 'y_min', 'x_max', 'y_max', 'image_width', 'image_height']].describe())

else:
    print("\nNo annotations found to display statistics.")
    print("Please check the dataset directory structure and annotation file formats.")
# Out:
# data.yaml not found. Will try to infer class names from annotations or use IDs.
# Info: Using root split directory for images and labels: garbage-detection-14/train
#
# Processing split: train
#   Image directory: garbage-detection-14/train, found 1365 image files.
#   Label directory: garbage-detection-14/train, found 0 .txt files and 0 .xml files.
# Info: Using root split directory for images and labels: garbage-detection-14/valid
#
# Processing split: valid
#   Image directory: garbage-detection-14/valid, found 315 image files.
#   Label directory: garbage-detection-14/valid, found 0 .txt files and 0 .xml files.
# Info: Using root split directory for images and labels: garbage-detection-14/test
#
# Processing split: test
#   Image directory: garbage-detection-14/test, found 184 image files.
#   Label directory: garbage-detection-14/test, found 0 .txt files and 0 .xml files.
#
# --- Annotation Loading Summary ---
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
#
# No annotations found to display statistics.
# Please check the dataset directory structure and annotation file formats.

# %% [markdown]
# **Reasoning**:
# Despite refining the base name extraction and checking multiple directory structures, the code still reports finding zero `.txt` and zero `.xml` files in the label directories. This contradicts the initial directory listing which showed `.txt` files alongside images in the split directories. The most likely reason for this discrepancy is a misunderstanding of the exact filename of the annotation files. I need to explicitly list the files in the `label_dir` and compare their names directly to the expected annotation filenames derived from the image files, including the `.rf.` part if necessary. I will add print statements to show the list of files in the label directory and the generated expected annotation filenames to pinpoint the mismatch.

# %%
# Correcting the dataset directory path based on the initial download output
dataset_dir = 'garbage-detection-14'

# --- Re-check data.yaml location ---
data_yaml_path = os.path.join(dataset_dir, 'data.yaml')
class_names = []
if os.path.exists(data_yaml_path):
    print(f"\nFound data.yaml at: {data_yaml_path}")
    try:
        with open(data_yaml_path, 'r') as f:
            data_yaml = yaml.safe_load(f)
            class_names = data_yaml.get('names', [])
            if class_names:
                print(f"Class names loaded from data.yaml: {class_names}")
            else:
                 print("Warning: 'names' not found or is empty in data.yaml. Will try to infer from annotations or use IDs.")
    except Exception as e:
        print(f"Error reading data.yaml: {e}")
        print("Will try to infer class names from annotations or use IDs.")
else:
    print("\ndata.yaml not found. Will try to infer class names from annotations or use IDs.")


# --- Collect Annotations (Refined Logic with detailed file checking) ---
all_annotations = []
splits = ['train', 'valid', 'test']

# Keep track of inferred class names if data.yaml was missing or empty
inferred_class_names = set()

if os.path.exists(dataset_dir): # Only proceed if dataset_dir exists
    for split in splits:
        split_dir = os.path.join(dataset_dir, split)

        if not os.path.exists(split_dir):
            print(f"Split directory not found: {split_dir}. Skipping.")
            continue

        # Determine image and label directories - check common structures
        image_dir = os.path.join(split_dir, 'images')
        label_dir = os.path.join(split_dir, 'labels')

        # If 'images' or 'labels' don't exist, assume files are in the root split directory
        if not os.path.exists(image_dir) or not os.path.exists(label_dir):
            image_dir = split_dir
            label_dir = split_dir
            print(f"Info: Using root split directory for images and labels: {split_dir}")


        if not os.path.exists(image_dir):
             print(f"Error: Image directory not found at {image_dir}. Skipping split {split}.")
             continue
        if not os.path.exists(label_dir):
            print(f"Error: Label directory not found at {label_dir}. Skipping split {split}.")
            continue


        files_in_image_dir = []
        if os.path.exists(image_dir):
             files_in_image_dir = os.listdir(image_dir)
        image_files = [f for f in files_in_image_dir if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

        files_in_label_dir = []
        if os.path.exists(label_dir):
             files_in_label_dir = os.listdir(label_dir)
        annotation_files_txt = {os.path.splitext(f)[0]: f for f in files_in_label_dir if f.lower().endswith('.txt')}
        annotation_files_xml = {os.path.splitext(f)[0]: f for f in files_in_label_dir if f.lower().endswith('.xml')}


        print(f"\nProcessing split: {split}")
        print(f"  Image directory: {image_dir}, found {len(image_files)} image files.")
        print(f"  Label directory: {label_dir}")

        # --- Debugging: List files in label directory ---
        print(f"  Files in label directory ({label_dir}) (first 10): {files_in_label_dir[:10]}...")
        print(f"  Number of .txt files found: {len(annotation_files_txt)}")
        print(f"  Number of .xml files found: {len(annotation_files_xml)}")
        # --- End Debugging ---


        for image_file in image_files:
            # Refined base name extraction: keep the .rf.* part as it seems to be in the annotation file names
            base_name = os.path.splitext(image_file)[0]
            # We expect the annotation file name to be exactly this base_name + .txt or .xml

            image_path = os.path.join(image_dir, image_file)

            annotations = []
            img_width, img_height = 0, 0

            # Attempt to read image dimensions first (needed for YOLO)
            try:
                with Image.open(image_path) as img:
                    img_width, img_height = img.size
            except Exception as e:
                print(f"Could not read image dimensions for {image_path}: {e}. Skipping image.")
                continue # Skip this image if dimensions cannot be read

            # Try parsing YOLO (.txt) annotations - look for base_name + .txt
            annotation_file_name_txt = base_name + '.txt'
            annotation_path_txt = os.path.join(label_dir, annotation_file_name_txt)

            # --- Debugging: Check if expected annotation file exists ---
            # print(f"  Checking for expected annotation file: {annotation_path_txt}")
            # --- End Debugging ---

            if os.path.exists(annotation_path_txt):
                # print(f"  Attempting to parse YOLO: {annotation_path_txt}") # Debugging line
                # Use class_names from data.yaml if available, otherwise YOLO parser uses IDs
                annotations = parse_yolo_annotation(annotation_path_txt, img_width, img_height, class_names if class_names else [f'class_{i}' for i in range(100)]) # Fallback names for YOLO if data.yaml empty/missing

            # If no YOLO annotations found for this image base name, try parsing VOC (.xml)
            annotation_file_name_xml = base_name + '.xml'
            annotation_path_xml = os.path.join(label_dir, annotation_file_name_xml)

            # --- Debugging: Check if expected XML annotation file exists ---
            # print(f"  Checking for expected XML annotation file: {annotation_path_xml}")
            # --- End Debugging ---

            if os.path.exists(annotation_path_xml):
                 # print(f"  Attempting to parse VOC: {annotation_path_xml}") # Debugging line
                 annotations = parse_voc_annotation(annotation_path_xml, class_names) # VOC parser uses class_names list to find IDs
                 # For VOC, image dimensions might be in XML, but we already read them from the image above.


            # Add found annotations to the list
            for ann in annotations:
                # Ensure dimensions are present (should be added by parsers, but double check)
                if 'image_width' not in ann or 'image_height' not in ann:
                     ann['image_width'] = img_width
                     ann['image_height'] = img_height

                ann['image_filename'] = image_file # Store the original image filename
                ann['split'] = split
                all_annotations.append(ann)

                # Collect class names if data.yaml was missing/empty
                if not class_names and 'class_name' in ann:
                     inferred_class_names.add(ann['class_name'])


# Create a pandas DataFrame from the collected annotations
annotations_df = pd.DataFrame(all_annotations)

# If class_names was empty, populate it from inferred names for better reporting
if not class_names and inferred_class_names:
     class_names = sorted(list(inferred_class_names))
     print(f"\nInferred class names from annotations: {class_names}")
     # Update class_id for annotations if they were added with class_id = -1
     if 'class_id' in annotations_df.columns:
         annotations_df['class_id'] = annotations_df['class_name'].apply(lambda name: class_names.index(name) if name in class_names else -1)


# --- Display Results ---
print("\n--- Annotation Loading Summary ---")

# Display the first few rows of the DataFrame
display(annotations_df.head())

# Display some basic info about the DataFrame
print("\nDataFrame Info:")
annotations_df.info()

# Display the number of annotations per split, only if the DataFrame is not empty
if not annotations_df.empty:
    print("\nNumber of annotations per split:")
    print(annotations_df['split'].value_counts())

    # Display the number of annotations per class
    print("\nNumber of annotations per class:")
    print(annotations_df['class_name'].value_counts())

    # Display summary statistics for bounding box coordinates
    print("\nBounding Box Coordinate Statistics:")
    display(annotations_df[['x_min', 'y_min', 'x_max', 'y_max', 'image_width', 'image_height']].describe())

else:
    print("\nNo annotations found to display statistics.")
    print("Please check the dataset directory structure and annotation file formats.")
    # Print the list of files found in the train label directory again for final check
    train_label_dir = os.path.join(dataset_dir, 'train')
    if os.path.exists(train_label_dir):
        print(f"\nFiles found in {train_label_dir}: {os.listdir(train_label_dir)[:20]}...") # Print first 20 items
# Out:
# data.yaml not found. Will try to infer class names from annotations or use IDs.
# Info: Using root split directory for images and labels: garbage-detection-14/train
#
# Processing split: train
#   Image directory: garbage-detection-14/train, found 1365 image files.
#   Label directory: garbage-detection-14/train
#   Files in label directory (garbage-detection-14/train) (first 10): ['929a16f0-R_1121_jpg.rf.2cb7c158ec86704ec06dc83bccbf35c4.jpg', 'Metal_522_jpg.rf.93481ac49a7ee9b3e52ad1c3aee2ad89.jpg', '5e179e44-R_124_jpg.rf.6411f513560e04588798934206144feb.jpg', 'glass501_jpg.rf.66d6fc358ca4e82acfb182b8c97c7b16.jpg', '15WJGM52A0NZ_jpg.rf.e99547634954f4772b5779df7a350775.jpg', 'Cup_Glass368_jpg.rf.d7683fbadd63fae82c54eb5154cccb70.jpg', 'Metal_524_jpg.rf.e3ea149c3cbac729e3262200430437f1.jpg', 'glass43_jpg.rf.65dfced2bd06a0cd65c5f0a6c586dce3.jpg', 'Cup_Glass076_jpg.rf.6a8d47c024bc984cdcbc9f90c2aea0c4.jpg', 'metal593_jpg.rf.77f46166ce48e9ecc2cdd7ad7031972c.jpg']...
#   Number of .txt files found: 0
#   Number of .xml files found: 0
# Info: Using root split directory for images and labels: garbage-detection-14/valid
#
# Processing split: valid
#   Image directory: garbage-detection-14/valid, found 315 image files.
#   Label directory: garbage-detection-14/valid
#   Files in label directory (garbage-detection-14/valid) (first 10): ['R_5205_jpg.rf.e4843929edf42be2f66026957c8a9490.jpg', 'Metal_37_jpg.rf.848fc54f1eaee1de5534ac1db4d11bbd.jpg', 'cf95e304-R_1407_jpg.rf.4da1a25d92ee0efac71cf2fe945e1e9a.jpg', 'a51902e0-R_64_jpg.rf.0c1dafd5fd195e31b4a71a72285750c3.jpg', '64VUFNVXK9TU_jpg.rf.e9e28ec3f78069d822718faa649ce0c0.jpg', 'R_5058_jpg.rf.9ff1b9337231c8eca09856451e92486a.jpg', 'Cup_Glass298_jpg.rf.2a5874697e8dae39edf05156c98d9d49.jpg', '54WJW8COSWYU_jpg.rf.203451d50c7f154764497e5e612096ae.jpg', '19f1be33-R_1427_jpg.rf.8b64eb7dca915844aa45eecb82a304fe.jpg', 'Metal_364_jpg.rf.9dac97a14abd03705a6d61c66b16e811.jpg']...
#   Number of .txt files found: 0
#   Number of .xml files found: 0
# Info: Using root split directory for images and labels: garbage-detection-14/test
#
# Processing split: test
#   Image directory: garbage-detection-14/test, found 184 image files.
#   Label directory: garbage-detection-14/test
#   Files in label directory (garbage-detection-14/test) (first 10): ['glass473_jpg.rf.92fcde92fbc5e2a58ae11b9a2728ba37.jpg', '89d2a416-R_1208_jpg.rf.0fe67e4849e9691d5d4faca2a513f6e4.jpg', '20221020_120352_jpg.rf.18183c250f35b062372fabb67daafa34.jpg', 'glass480_jpg.rf.8b0b977d41de01d15c02adc64abbcfbf.jpg', 'Cup_Glass231_jpg.rf.daf826f04462f1e61c2192f4b3b2baca.jpg', '20221020_123037_jpg.rf.34f29172f6d5cf8c51b18984b119766f.jpg', 'glass-428_jpg.rf.ff22b0cf5bee7c853721ea16c1fb341c.jpg', '1TBKD9FYTLU3_jpg.rf.0bfe1a101c823e5a7b34228c0844c6fe.jpg', 'glass234_jpg.rf.6896b300d0480fd2c77ded5169281d1b.jpg', 'glass415_jpg.rf.f4e7f34b30c7a6f7cfbfb585d5f34040.jpg']...
#   Number of .txt files found: 0
#   Number of .xml files found: 0
#
# --- Annotation Loading Summary ---
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
#
# No annotations found to display statistics.
# Please check the dataset directory structure and annotation file formats.
#
# Files found in garbage-detection-14/train: ['929a16f0-R_1121_jpg.rf.2cb7c158ec86704ec06dc83bccbf35c4.jpg', 'Metal_522_jpg.rf.93481ac49a7ee9b3e52ad1c3aee2ad89.jpg', '5e179e44-R_124_jpg.rf.6411f513560e04588798934206144feb.jpg', 'glass501_jpg.rf.66d6fc358ca4e82acfb182b8c97c7b16.jpg', '15WJGM52A0NZ_jpg.rf.e99547634954f4772b5779df7a350775.jpg', 'Cup_Glass368_jpg.rf.d7683fbadd63fae82c54eb5154cccb70.jpg', 'Metal_524_jpg.rf.e3ea149c3cbac729e3262200430437f1.jpg', 'glass43_jpg.rf.65dfced2bd06a0cd65c5f0a6c586dce3.jpg', 'Cup_Glass076_jpg.rf.6a8d47c024bc984cdcbc9f90c2aea0c4.jpg', 'metal593_jpg.rf.77f46166ce48e9ecc2cdd7ad7031972c.jpg', 'Cup_Glass113_jpg.rf.d90be4497c5415557381e2edfc3319db.jpg', '0478E1ES35FY_jpg.rf.72ff927e2136d592bacc5d7433e67697.jpg', '4dafbe19-R_1598_jpg.rf.1986e1f54ad655d1fb9d9dae832f9f5c.jpg', 'R_5267_jpg.rf.d976ab11d7460c82cba71cf2546fb35f.jpg', '9c34aae2-R_1295_jpg.rf.c74ffaf620c5493e00fc3e6f97c1a75c.jpg', 'glass438_jpg.rf.03e859393d575d5e70bc426037793487.jpg', 'p_sm_36_jpg.rf.9cbfb37f044541677f2b45f794117b6f.jpg', 'Cup_Glass301_jpg.rf.5617b25f2c2145bb081deb73405c4ca3.jpg', 'glass-280_jpg.rf.2a9322dfc93e529549cf718f658ae0df.jpg', '20221020_120040_jpg.rf.669621022e757e1d39f86a7085303c0d.jpg']...

# %% [markdown]
# ## Analyze class distribution
#
# ### Subtask:
# Analyze the distribution of different object classes in the dataset.

# %% [markdown]
# **Reasoning**:
# Check if the annotations_df DataFrame is empty. If it is, print a message indicating that class distribution cannot be analyzed because the data is not loaded. If not empty, calculate and print the class distribution and then visualize it using a bar plot.

# %%
import matplotlib.pyplot as plt

# Check if the annotations_df DataFrame is empty
if annotations_df.empty:
    print("Class distribution cannot be analyzed because the annotations_df DataFrame is empty. Data was not loaded.")
else:
    # Calculate the value counts for the 'class_name' column
    class_distribution = annotations_df['class_name'].value_counts()

    # Print the resulting class distribution
    print("\nAnnotation Class Distribution:")
    print(class_distribution)

    # Visualize the class distribution using a bar plot
    plt.figure(figsize=(10, 6))
    class_distribution.plot(kind='bar')
    plt.title('Distribution of Annotation Classes')
    plt.xlabel('Class Name')
    plt.ylabel('Number of Annotations')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Class distribution cannot be analyzed because the annotations_df DataFrame is empty. Data was not loaded.

# %% [markdown]
# ## Analyze image properties
#
# ### Subtask:
# Analyze image properties such as dimensions and aspect ratios.

# %% [markdown]
# **Reasoning**:
# Check if the annotations_df DataFrame is empty and proceed with image property analysis if it's not, following the instructions to calculate aspect ratios, print statistics, and generate histograms.

# %%
import matplotlib.pyplot as plt

# 1. Check if the annotations_df DataFrame is empty.
if annotations_df.empty:
    print("Image properties cannot be analyzed because the annotations_df DataFrame is empty. Data was not loaded.")
else:
    # 2. Calculate the aspect ratio for each image.
    annotations_df['aspect_ratio'] = annotations_df['image_width'] / annotations_df['image_height']

    # 3. Print summary statistics.
    print("\nSummary Statistics for Image Properties:")
    display(annotations_df[['image_width', 'image_height', 'aspect_ratio']].describe())

    # 4. Create a histogram for image widths.
    plt.figure(figsize=(18, 5)) # Adjust figure size for multiple plots

    plt.subplot(1, 3, 1) # 1 row, 3 columns, 1st plot
    annotations_df['image_width'].hist(bins=20)
    plt.title('Distribution of Image Widths')
    plt.xlabel('Image Width')
    plt.ylabel('Frequency')

    # 5. Create a histogram for image heights.
    plt.subplot(1, 3, 2) # 1 row, 3 columns, 2nd plot
    annotations_df['image_height'].hist(bins=20)
    plt.title('Distribution of Image Heights')
    plt.xlabel('Image Height')
    plt.ylabel('Frequency')

    # 6. Create a histogram for image aspect ratios.
    plt.subplot(1, 3, 3) # 1 row, 3 columns, 3rd plot
    annotations_df['aspect_ratio'].hist(bins=20)
    plt.title('Distribution of Image Aspect Ratios')
    plt.xlabel('Aspect Ratio')
    plt.ylabel('Frequency')

    # 7. Display all generated plots.
    plt.tight_layout()
    plt.show()
# Out:
# Image properties cannot be analyzed because the annotations_df DataFrame is empty. Data was not loaded.

# %% [markdown]
# ## Analyze annotation properties
#
# ### Subtask:
# Analyze annotation properties such as bounding box sizes and aspect ratios.

# %% [markdown]
# **Reasoning**:
# Check if the annotations_df DataFrame is empty and proceed with calculations and visualizations if it's not empty.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Check if the annotations_df DataFrame is empty.
if annotations_df.empty:
    print("Annotation properties cannot be analyzed because the annotations_df DataFrame is empty. Data was not loaded.")
else:
    # 2. Calculate the width and height of each bounding box.
    annotations_df['bbox_width'] = annotations_df['x_max'] - annotations_df['x_min']
    annotations_df['bbox_height'] = annotations_df['y_max'] - annotations_df['y_min']

    # 3. Calculate the aspect ratio of each bounding box, handling division by zero.
    annotations_df['bbox_aspect_ratio'] = annotations_df['bbox_width'] / annotations_df['bbox_height']
    # Replace infinite values resulting from division by zero with NaN
    annotations_df.replace([np.inf, -np.inf], np.nan, inplace=True)


    # 4. Print summary statistics for the bounding box dimensions and aspect ratio.
    print("\nSummary Statistics for Bounding Box Properties:")
    display(annotations_df[['bbox_width', 'bbox_height', 'bbox_aspect_ratio']].describe())

    # 5. Create histograms to visualize the distributions.
    plt.figure(figsize=(18, 5)) # Adjust figure size for multiple plots

    # Histogram for bbox_width
    plt.subplot(1, 3, 1) # 1 row, 3 columns, 1st plot
    # Drop NaN values for plotting aspect ratio if they exist after handling division by zero
    annotations_df['bbox_width'].dropna().hist(bins=20)
    plt.title('Distribution of Bounding Box Widths')
    plt.xlabel('Bounding Box Width (pixels)')
    plt.ylabel('Frequency')

    # Histogram for bbox_height
    plt.subplot(1, 3, 2) # 1 row, 3 columns, 2nd plot
    # Drop NaN values for plotting aspect ratio if they exist after handling division by zero
    annotations_df['bbox_height'].dropna().hist(bins=20)
    plt.title('Distribution of Bounding Box Heights')
    plt.xlabel('Bounding Box Height (pixels)')
    plt.ylabel('Frequency')


    # Histogram for bbox_aspect_ratio
    plt.subplot(1, 3, 3) # 1 row, 3 columns, 3rd plot
    # Drop NaN values for plotting aspect ratio if they exist after handling division by zero
    annotations_df['bbox_aspect_ratio'].dropna().hist(bins=20)
    plt.title('Distribution of Bounding Box Aspect Ratios')
    plt.xlabel('Aspect Ratio (Width / Height)')
    plt.ylabel('Frequency')

    # 6. Add titles and labels - done within each subplot.
    # 7. Use plt.tight_layout() and plt.show()
    plt.tight_layout()
    plt.show()
# Out:
# Annotation properties cannot be analyzed because the annotations_df DataFrame is empty. Data was not loaded.

# %% [markdown]
# ## Visualize the annotations
#
# ### Subtask:
# Visualize the bounding boxes and masks to understand the spatial distribution of objects.

# %% [markdown]
# ## Generate reports
#
# ### Subtask:
# Generate summary reports of the dataset analysis.

# %% [markdown]
# **Reasoning**:
# Check if the annotations_df DataFrame is empty and print a message if it is, otherwise generate and print the summary report.

# %%
# Check if the annotations_df DataFrame is empty
if annotations_df.empty:
    print("Summary reports cannot be generated because the annotations_df DataFrame is empty. Data was not loaded.")
else:
    print("--- Dataset Summary Report ---")

    # 1. Total number of images and annotations.
    num_unique_images = annotations_df['image_filename'].nunique()
    total_annotations = len(annotations_df)
    print(f"\nTotal number of images: {num_unique_images}")
    print(f"Total number of annotations: {total_annotations}")

    # 2. Number of unique classes and their distribution.
    unique_classes = annotations_df['class_name'].unique()
    print(f"\nNumber of unique classes: {len(unique_classes)}")
    print("\nAnnotation Class Distribution:")
    print(annotations_df['class_name'].value_counts())

    # 3. Summary statistics for image dimensions.
    # Ensure 'image_width' and 'image_height' columns exist and are numeric
    if 'image_width' in annotations_df.columns and 'image_height' in annotations_df.columns:
        try:
            # Calculate aspect ratio, handle potential division by zero
            annotations_df['image_aspect_ratio'] = annotations_df['image_width'] / annotations_df['image_height']
            annotations_df.replace([np.inf, -np.inf], np.nan, inplace=True) # Replace inf with NaN

            print("\nSummary Statistics for Image Dimensions:")
            display(annotations_df[['image_width', 'image_height', 'image_aspect_ratio']].describe())
        except Exception as e:
            print(f"Could not compute image dimension statistics: {e}")
            print("Please ensure 'image_width' and 'image_height' columns contain numeric data.")
            display(annotations_df[['image_width', 'image_height']].head()) # Show head for debugging
    else:
        print("\nImage dimension columns ('image_width', 'image_height') not found in DataFrame.")


    # 4. Summary statistics for bounding box dimensions.
    # Ensure 'bbox_width', 'bbox_height', 'bbox_aspect_ratio' columns exist
    if 'bbox_width' in annotations_df.columns and 'bbox_height' in annotations_df.columns and 'bbox_aspect_ratio' in annotations_df.columns:
         print("\nSummary Statistics for Bounding Box Dimensions:")
         display(annotations_df[['bbox_width', 'bbox_height', 'bbox_aspect_ratio']].describe())
    else:
         print("\nBounding box dimension columns ('bbox_width', 'bbox_height', 'bbox_aspect_ratio') not found in DataFrame.")
         # Attempt to calculate if possible from x_min, y_min, etc.
         if all(col in annotations_df.columns for col in ['x_min', 'y_min', 'x_max', 'y_max']):
             try:
                 annotations_df['bbox_width'] = annotations_df['x_max'] - annotations_df['x_min']
                 annotations_df['bbox_height'] = annotations_df['y_max'] - annotations_df['y_min']
                 annotations_df['bbox_aspect_ratio'] = annotations_df['bbox_width'] / annotations_df['bbox_height']
                 annotations_df.replace([np.inf, -np.inf], np.nan, inplace=True) # Replace inf with NaN
                 print("Attempted to calculate bounding box dimensions:")
                 display(annotations_df[['bbox_width', 'bbox_height', 'bbox_aspect_ratio']].describe())
             except Exception as e:
                 print(f"Could not calculate bounding box dimension statistics: {e}")
                 print("Please ensure bounding box coordinate columns contain numeric data.")
                 display(annotations_df[['x_min', 'y_min', 'x_max', 'y_max']].head()) # Show head for debugging
         else:
            print("Bounding box coordinate columns ('x_min', 'y_min', 'x_max', 'y_max') not found in DataFrame.")


    print("\n--- Report End ---")
# Out:
# Summary reports cannot be generated because the annotations_df DataFrame is empty. Data was not loaded.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset directory `garbage-detection-14` was successfully located and contained `train`, `valid`, and `test` subdirectories.
# *   The `data.yaml` file was not found in the expected location within the dataset directory.
# *   Despite multiple attempts and checks for common dataset structures (root split directory, `images`/`labels` subdirectories), no `.txt` (YOLO) or `.xml` (VOC) annotation files were found corresponding to the image files.
# *   Directory listings during debugging confirmed that the files present in the locations expected to contain labels were the image files themselves, indicating the absence of annotation files in the downloaded structure.
# *   Consequently, the `annotations_df` DataFrame remained empty throughout the process.
#
# ### Insights or Next Steps
#
# *   The primary issue is the lack of discoverable annotation files in the downloaded dataset structure. Verify the source of the dataset and ensure that annotation files are included and follow a standard naming convention and directory structure (e.g., YOLO `.txt` files in a `labels` subdirectory matching image names in an `images` subdirectory, or VOC `.xml` files).
# *   If the dataset source cannot be changed, manual inspection of the dataset contents is required to understand the actual location and format of annotation files, or if they are missing entirely, the dataset cannot be used for object detection training/analysis without obtaining or generating annotations.
